# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import joblib
from pathlib import Path
from datetime import datetime

# Core ML
import lightgbm as lgb
from sklearn.linear_model import Ridge
from sklearn.metrics import (
    r2_score, mean_absolute_error, mean_squared_error,
    mean_absolute_percentage_error
)
from sklearn.preprocessing import LabelEncoder

# Excel output
from openpyxl import Workbook
from openpyxl.styles import Font, Alignment
from openpyxl.utils import get_column_letter

# Optional stacking libraries
try:
    import xgboost as xgb
    _HAS_XGB = True
    print("[OK] XGBoost available")
except ImportError:
    _HAS_XGB = False
    print("[WARN] xgboost not installed — using LightGBM only")

try:
    from catboost import CatBoostRegressor
    _HAS_CAT = True
    print("[OK] CatBoost available")
except ImportError:
    _HAS_CAT = False
    print("[WARN] catboost not installed")

try:
    import optuna
    optuna.logging.set_verbosity(optuna.logging.WARNING)
    _HAS_OPTUNA = True
    print("[OK] Optuna available — automated HPO enabled")
except ImportError:
    _HAS_OPTUNA = False
    print("[INFO] Optuna not installed — using hand-tuned params")

print("\n[READY] All imports done.")
# Out:
# [OK] XGBoost available
# [OK] CatBoost available
# [OK] Optuna available — automated HPO enabled
#
# [READY] All imports done.

# %%
# ── File paths ─────────────────────────────────────────────────────────────────
CSV_PATH   = Path("latest_all_vehicles.csv")   
MODEL_OUT  = Path("lgbm_vehicle_price_model_v3_2_0.pkl")
STACK_OUT  = Path("stacking_meta_model_v3_2_0.pkl")
EXCEL_OUT  = Path("vehicle_price_forecast_2_0.xlsx")          # ← FINAL EXCEL OUTPUT

# ── Data thresholds ────────────────────────────────────────────────────────────
PRICE_CAP    = 30_000_000   # Remove listings > 30M LKR
MILEAGE_CAP  = 1_000_000    # Remove listings > 1M km
PRICE_FLOOR  = 100_000      # Remove listings < 100K LKR

# ── Training config ────────────────────────────────────────────────────────────
TEST_SPLIT_DAYS = 90         # Last 90 days = test set (temporal, no leakage)
RANDOM_STATE    = 42
OPTUNA_TRIALS   = 5        # Increase for better accuracy (costs time)

# ── Excel template months (must match your historical data range) ──────────────
# These are the 6 historical months shown in the template
TEMPLATE_MONTHS = ["2025-11", "2025-12", "2026-01", "2026-02", "2026-03", "2026-04"]
MONTH_HEADERS   = ["NOV 2025", "DEC 2025", "JAN 2026", "FEB 2026", "MARCH 2026", "APRIL 2026"]

# ── Query date: the "today" from which Next Week / Next Month are forecast ─────
QUERY_DATE = datetime.today().strftime('%Y-%m-%d')

print(f"CSV      : {CSV_PATH}")
print(f"Excel out: {EXCEL_OUT}")
print(f"Query date (forecast anchor): {QUERY_DATE}")
# Out:
# CSV      : latest_all_vehicles.csv
# Excel out: vehicle_price_forecast_2_0.xlsx
# Query date (forecast anchor): 2026-03-22

# %%
# DIAGNOSTIC — Check raw CSV format
import pandas as pd
from pathlib import Path

df_raw = pd.read_csv(CSV_PATH)

print(f"CSV shape: {df_raw.shape}")
print(f"\nColumn names:\n{list(df_raw.columns)}\n")
print(f"Sample 'published date' values (first 20):")
print(df_raw['published date'].head(20).tolist())
print(f"\nNull count in 'published date': {df_raw['published date'].isna().sum()}")
print(f"Unique date values (sample): {df_raw['published date'].unique()[:10]}")
# Out:
# CSV shape: (13353, 9)
#
# Column names:
# ['Vehicle Type', 'Make', 'Model', 'Year', 'Price', 'Milleage', 'District', 'published date', 'Vehicle URL']
#
# Sample 'published date' values (first 20):
# ['Mar 18', 'Mar 17', '13h ago', 'Mar 13', 'Just now', '1m ago', '1m ago', '1m ago', '2m ago', '2m ago', '2m ago', '2m ago', '3m ago', '3m ago', '3m ago', '3m ago', '3m ago', '3m ago', '4m ago', '4m ago']
#
# Null count in 'published date': 0
# Unique date values (sample): ['Mar 18' 'Mar 17' '13h ago' 'Mar 13' 'Just now' '1m ago' '2m ago'
#  '3m ago' '4m ago' '5m ago']

# %%
# IMPROVED DATE PARSER — Add this cell BEFORE load_and_clean()
import re

def parse_scraped_date(val):
    """
    Robust parser for web-scraped dates. Handles:
    - Relative: "Just now", "5m ago", "2h ago", "1d ago"
    - Named: "Yesterday"
    - Month-Day: "Mar 18", "Jan 05"
    - Absolute: "DD/MM/YYYY", "YYYY-MM-DD"
    - Fallback: pandas infer_datetime_format
    """
    val = str(val).strip()
    if not val or val.lower() == 'nan':
        return pd.NaT
    
    TODAY = pd.Timestamp.today().normalize()

    # 1. Just now / Xm ago (minutes)
    if val == 'Just now' or re.match(r'^\d+m ago$', val):
        return TODAY

    # 2. Xh ago (hours)
    if re.match(r'^\d+h ago$', val):
        return TODAY
    
    # 3. Xd ago (days)
    m = re.match(r'^(\d+)d ago$', val)
    if m:
        return TODAY - pd.Timedelta(days=int(m.group(1)))

    # 4. Yesterday / Today
    if val.lower() == 'yesterday':
        return TODAY - pd.Timedelta(days=1)
    if val.lower() == 'today':
        return TODAY

    # 5. "Mar 18" / "Jan 5" (month + day)
    m = re.match(r'^([A-Za-z]{3})\s*(\d{1,2})$', val)
    if m:
        try:
            candidate = pd.Timestamp(f'{m.group(1)} {m.group(2)} {TODAY.year}')
            if candidate > TODAY:
                candidate = pd.Timestamp(f'{m.group(1)} {m.group(2)} {TODAY.year - 1}')
            return candidate
        except:
            pass

    # 6. "DD/MM/YYYY" or "DD-MM-YYYY"
    m = re.match(r'^(\d{1,2})[/-](\d{1,2})[/-](\d{4})$', val)
    if m:
        try:
            day, month, year = int(m.group(1)), int(m.group(2)), int(m.group(3))
            return pd.Timestamp(year=year, month=month, day=day)
        except:
            pass

    # 7. Fallback: Try pandas parser
    try:
        parsed = pd.to_datetime(val, infer_datetime_format=True, errors='coerce')
        if pd.notna(parsed):
            return parsed
    except:
        pass

    return pd.NaT

# %%
def load_and_clean(CSV_PATH: Path) -> pd.DataFrame:
    """Load CSV, parse dates, clean data, and return DataFrame."""
    df = pd.read_csv(CSV_PATH)
    print(f"[LOAD] CSV loaded: {df.shape}")
    print(f"[LOAD] Columns: {list(df.columns)}")
    
    # Drop unnamed columns
    df.drop(columns=[c for c in df.columns if 'Unnamed' in c], inplace=True, errors='ignore')
    
    # Parse dates and show sample failures
    print("\n[DATE] Parsing dates...")
    df['published date'] = df['published date'].apply(parse_scraped_date)
    nat_cnt = df['published date'].isna().sum()
    parsed_cnt = len(df) - nat_cnt
    print(f"[DATE] Parsed: {parsed_cnt:,} | Failed: {nat_cnt:,}")
    
    if parsed_cnt > 0:
        print(f"[DATE] Date range: {df['published date'].min().date()} → {df['published date'].max().date()}")
        if nat_cnt > 0:
            unparseable = df[df['published date'].isna()]['published date'].iloc[:5].tolist()
            print(f"[DATE] Sample unparseable: {unparseable[:3]}")
    else:
        print("[ERROR] ALL DATES FAILED TO PARSE!")
        return df
    
    # ─── PARSE PRICE COLUMN (may have "Rs. " prefix and commas) ──────────────────
    print("\n[PRICE] Parsing price format...")
    def parse_price(val):
        if pd.isna(val):
            return np.nan
        val_str = str(val).strip()
        if val_str.lower() in ['negotiable', 'ask', 'n/a', 'na', '']:
            return np.nan
        # Remove "Rs. " prefix, spaces, and commas
        val_str = val_str.replace('Rs.', '').replace('Rs', '').replace(',', '').strip()
        try:
            price = float(val_str)
            # Filter out placeholder values like "Rs. 1"
            if price < 10000:
                return np.nan
            return price
        except (ValueError, TypeError):
            return np.nan
    
    df['Price'] = df['Price'].apply(parse_price)
    valid_prices = df['Price'].notna().sum()
    print(f"[PRICE] Valid prices: {valid_prices:,}")
    
    # Drop rows missing critical fields
    required_cols = ['Make', 'Model', 'Year', 'Milleage', 'published date']
    df.dropna(subset=required_cols, inplace=True)
    print(f"[CLEAN] After dropna: {df.shape}")
    
    # Type casting
    df['Year']           = pd.to_numeric(df['Year'], errors='coerce')
    df['Milleage']       = pd.to_numeric(df['Milleage'], errors='coerce')
    df.dropna(subset=['Price', 'Milleage', 'published date'], inplace=True)
    
    # Outlier removal (price and mileage)
    df = df[(df['Price'] > PRICE_FLOOR) & (df['Price'] < PRICE_CAP)]
    df = df[(df['Milleage'] >= 0) & (df['Milleage'] < MILEAGE_CAP)]
    print(f"[CLEAN] After outlier removal: {df.shape}")
    
    # URL deduplication
    url_col = next((c for c in df.columns if 'url' in c.lower()), None)
    if url_col:
        before = len(df)
        df.drop_duplicates(subset=[url_col], keep='last', inplace=True)
        print(f"[DEDUP] Removed {before - len(df):,} duplicate listings")
    
    # Normalize text
    for col in ['Make', 'Model']:
        df[col] = df[col].astype(str).str.strip().str.upper()
    
    # Sort and reset
    df.sort_values(['Make', 'Model', 'published date'], inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    print(f"\n[DATA] {len(df):,} rows | {df['Make'].nunique()} makes | "
          f"{df['Model'].nunique()} models | {df['Year'].min()}–{df['Year'].max()}\n")
    
    return df


# Run it
raw_df = load_and_clean(CSV_PATH)
# Out:
# [LOAD] CSV loaded: (13353, 9)
# [LOAD] Columns: ['Vehicle Type', 'Make', 'Model', 'Year', 'Price', 'Milleage', 'District', 'published date', 'Vehicle URL']
#
# [DATE] Parsing dates...
# [DATE] Parsed: 13,353 | Failed: 0
# [DATE] Date range: 2025-12-21 → 2026-03-22
#
# [PRICE] Parsing price format...
# [PRICE] Valid prices: 10,349
# [CLEAN] After dropna: (11732, 9)
# [CLEAN] After outlier removal: (8928, 9)
# [DEDUP] Removed 0 duplicate listings
#
# [DATA] 8,928 rows | 62 makes | 2107 models | 1948.0–2026.0

# %%
# PRICE RANGE DIAGNOSTIC
print("\n[PRICE DIAGNOSTIC] Checking actual price range in data...")
df_check = pd.read_csv(CSV_PATH)

print(f"Raw CSV shape: {df_check.shape}")
print(f"Raw data types:\n{df_check.dtypes}\n")

# Check Price column
print(f"Price column sample (first 10):")
print(df_check['Price'].head(10).tolist())
print(f"Price dtype: {df_check['Price'].dtype}")
print(f"Price nulls: {df_check['Price'].isna().sum()}")

# Check Milleage column
print(f"\nMilleage column sample (first 10):")
print(df_check['Milleage'].head(10).tolist())
print(f"Milleage dtype: {df_check['Milleage'].dtype}")
print(f"Milleage nulls: {df_check['Milleage'].isna().sum()}")

# Try converting
df_check['Price'] = pd.to_numeric(df_check['Price'], errors='coerce')
df_check['Milleage'] = pd.to_numeric(df_check['Milleage'], errors='coerce')

print(f"\nAfter to_numeric conversion:")
print(f"Price nulls: {df_check['Price'].isna().sum()}")
print(f"Milleage nulls: {df_check['Milleage'].isna().sum()}")

# Check what's available
df_valid = df_check.dropna(subset=['Price', 'Milleage'])
print(f"\nRows with valid Price & Milleage: {len(df_valid)} / {len(df_check)}")

if len(df_valid) > 0:
    print(f"\nPrice range in valid rows:")
    print(f"  Min: {df_valid['Price'].min():,.0f}")
    print(f"  Max: {df_valid['Price'].max():,.0f}")
    print(f"  Mean: {df_valid['Price'].mean():,.0f}")
    print(f"  Median: {df_valid['Price'].median():,.0f}")
# Out:
# [PRICE DIAGNOSTIC] Checking actual price range in data...
# Raw CSV shape: (13353, 9)
# Raw data types:
# Vehicle Type       object
# Make               object
# Model              object
# Year              float64
# Price              object
# Milleage          float64
# District           object
# published date     object
# Vehicle URL        object
# dtype: object
#
# Price column sample (first 10):
# ['Negotiable', 'Rs. 11,990,000', 'Rs. 7,625,000', 'Negotiable', 'Rs. 1,300,000', 'Rs. 1', 'Rs. 8,250,000', 'Rs. 1', 'Rs. 1', 'Rs. 275,000']
# Price dtype: object
# Price nulls: 0
#
# Milleage column sample (first 10):
# [95360.0, 89500.0, 160000.0, 180000.0, nan, 129000.0, 180000.0, 129000.0, 129000.0, 60000.0]
# Milleage dtype: float64
# Milleage nulls: 1614
#
# After to_numeric conversion:
# Price nulls: 13353
# Milleage nulls: 1614
#
# Rows with valid Price & Milleage: 0 / 13353

# %%
def derive_condition(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    def _cond(row):
        yr, km = row['Year'], row['Milleage']
        if yr >= 2022:
            if km < 5_000:   return 'Brand New'
            if km <= 50_000: return 'Recondition'
        return 'Used'
    df['Condition'] = df.apply(_cond, axis=1)
    print("[CONDITION]", df['Condition'].value_counts().to_dict())
    return df

raw_df = derive_condition(raw_df)
# Out:
# [CONDITION] {'Used': 8190, 'Recondition': 404, 'Brand New': 334}

# %%
def engineer_features(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    # A) Time features
    df['post_year']   = df['published date'].dt.year
    df['month']       = df['published date'].dt.month
    df['quarter']     = df['published date'].dt.quarter
    df['day_of_year'] = df['published date'].dt.dayofyear
    df['week']        = df['published date'].dt.isocalendar().week.astype(int)

    # B) Age / depreciation (log + squared for non-linear curve)
    df['Car_Age']    = (df['post_year'] - df['Year']).clip(lower=0)
    df['log_car_age'] = np.log1p(df['Car_Age'])
    df['car_age_sq']  = df['Car_Age'] ** 2

    # C) Mileage features (log-scaled: mileage is right-skewed)
    df['log_milleage']    = np.log1p(df['Milleage'])
    df['km_per_year']     = df['Milleage'] / df['Car_Age'].replace(0, 0.5)
    df['log_km_per_year'] = np.log1p(df['km_per_year'])

    # D) Market anchor statistics per Make+Model group (NOT leakage — population stats)
    grp = df.groupby(['Make', 'Model'])['Price']
    df['grp_median_price'] = grp.transform('median')
    df['grp_mean_price']   = grp.transform('mean')
    df['grp_std_price']    = grp.transform('std').fillna(0)
    df['grp_count']        = grp.transform('count')

    # Year-level anchor
    grp2 = df.groupby(['Make', 'Model', 'Year'])['Price']
    df['yr_median_price'] = grp2.transform('median')
    df['yr_mean_price']   = grp2.transform('mean')

    # E) Temporal lag features (leak-free because data is sorted chronologically)
    df['lag_1'] = df.groupby(['Make', 'Model'])['Price'].shift(1)
    df['lag_2'] = df.groupby(['Make', 'Model'])['Price'].shift(2)
    df['lag_7'] = df.groupby(['Make', 'Model'])['Price'].shift(7)
    df['rolling_mean_3'] = (df.groupby(['Make', 'Model'])['Price']
                            .transform(lambda x: x.shift(1).rolling(3, min_periods=1).mean()))
    df['rolling_mean_7'] = (df.groupby(['Make', 'Model'])['Price']
                            .transform(lambda x: x.shift(1).rolling(7, min_periods=1).mean()))

    # Fill NaN lags with group median (safe — no leakage)
    for col in ['lag_1', 'lag_2', 'lag_7', 'rolling_mean_3', 'rolling_mean_7']:
        df[col].fillna(df['grp_median_price'], inplace=True)

    # F) Relative ratio signal
    df['price_vs_median'] = df['lag_1'] / df['grp_median_price'].replace(0, 1)

    # G) Condition ordinal encoding
    cond_map = {'Brand New': 3, 'Recondition': 2, 'Used': 1, 'Unknown': 0}
    df['condition_code'] = df['Condition'].map(cond_map).fillna(1).astype(int)

    print(f"[FEATURES] {df.shape[1]} columns | {len(df):,} rows")
    return df


eng_df = engineer_features(raw_df)
# Out:
# [FEATURES] 34 columns | 8,928 rows

# %%
NUMERIC_FEATURES = [
    'Car_Age', 'log_car_age', 'car_age_sq',
    'log_milleage', 'log_km_per_year',
    'month', 'quarter', 'day_of_year', 'week',
    'lag_1', 'lag_2', 'lag_7',
    'rolling_mean_3', 'rolling_mean_7',
    'grp_median_price', 'grp_mean_price', 'grp_std_price', 'grp_count',
    'yr_median_price', 'yr_mean_price',
    'price_vs_median',
    'condition_code',
]
CATEGORICAL_FEATURES = ['Make', 'Model']
ALL_FEATURES = NUMERIC_FEATURES + CATEGORICAL_FEATURES

print(f"Total features: {len(ALL_FEATURES)}  ({len(NUMERIC_FEATURES)} numeric + {len(CATEGORICAL_FEATURES)} categorical)")
# Out:
# Total features: 24  (22 numeric + 2 categorical)

# %%
def log_target(y):   return np.log1p(y)
def exp_target(y):   return np.expm1(y)

print("log_target / exp_target ready.")
# Out:
# log_target / exp_target ready.

# %%
# DIAGNOSTIC — Check actual date span before training
if len(eng_df) > 0:
    date_min = eng_df['published date'].min()
    date_max = eng_df['published date'].max()
    days_spanned = (date_max - date_min).days
    
    print(f"[DATE SPAN DIAGNOSTIC]")
    print(f"  Min date: {date_min}")
    print(f"  Max date: {date_max}")
    print(f"  Total days spanned: {days_spanned}")
    print(f"  Current TEST_SPLIT_DAYS: {TEST_SPLIT_DAYS}")
    print(f"  STATUS: {'✓ OK' if days_spanned >= TEST_SPLIT_DAYS else '✗ PROBLEM — TEST_SPLIT_DAYS exceeds data span'}")
    
    if days_spanned < TEST_SPLIT_DAYS:
        recommended = max(7, days_spanned // 3)
        print(f"  RECOMMENDED: Set TEST_SPLIT_DAYS = {recommended} (1/3 of actual span)")
else:
    print("[ERROR] eng_df is empty!")
# Out:
# [DATE SPAN DIAGNOSTIC]
#   Min date: 2025-12-21 00:00:00
#   Max date: 2026-03-22 00:00:00
#   Total days spanned: 91
#   Current TEST_SPLIT_DAYS: 90
#   STATUS: ✓ OK

# %%
def _encode_for_xgb(X):
    """Convert categorical features to numeric for XGBoost."""
    X = X.copy()
    for col in CATEGORICAL_FEATURES:
        X[col] = LabelEncoder().fit_transform(X[col].astype(str))
    return X


def get_best_params(X_tr, y_tr, X_va, y_va):
    """Hyperparameter optimization with Optuna or return hand-tuned params."""
    
    if not _HAS_OPTUNA:
        print("[HPO] Using hand-tuned params")
        return dict(n_estimators=4000, learning_rate=0.01, num_leaves=40,
                    min_child_samples=30, subsample=0.80, colsample_bytree=0.80,
                    reg_alpha=0.05, reg_lambda=0.10, max_depth=8,
                    min_split_gain=0.01, random_state=RANDOM_STATE, verbose=-1)

    def objective(trial):
        params = dict(
            n_estimators      = trial.suggest_int('n_estimators', 1000, 5000),
            learning_rate     = trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
            num_leaves        = trial.suggest_int('num_leaves', 20, 80),
            min_child_samples = trial.suggest_int('min_child_samples', 10, 60),
            subsample         = trial.suggest_float('subsample', 0.6, 1.0),
            colsample_bytree  = trial.suggest_float('colsample_bytree', 0.6, 1.0),
            reg_alpha         = trial.suggest_float('reg_alpha', 1e-4, 1.0, log=True),
            reg_lambda        = trial.suggest_float('reg_lambda', 1e-4, 1.0, log=True),
            max_depth         = trial.suggest_int('max_depth', 4, 12),
            min_split_gain    = trial.suggest_float('min_split_gain', 0.0, 0.5),
            random_state=RANDOM_STATE, verbose=-1,
        )
        m = lgb.LGBMRegressor(**params)
        m.fit(X_tr, y_tr, eval_set=[(X_va, y_va)],
              categorical_feature=CATEGORICAL_FEATURES,
              callbacks=[lgb.early_stopping(100, verbose=False)])
        preds = exp_target(m.predict(X_va))
        return mean_absolute_percentage_error(exp_target(y_va), preds)

    print(f"[HPO] Running {OPTUNA_TRIALS} Optuna trials…")
    study = optuna.create_study(direction='minimize',
                                sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE))
    study.optimize(objective, n_trials=OPTUNA_TRIALS, show_progress_bar=True)
    print(f"[HPO] Best MAPE: {study.best_value*100:.2f}%")
    return {**study.best_params, 'random_state': RANDOM_STATE, 'verbose': -1}


def train_model(df: pd.DataFrame):
    """
    Train LightGBM + optional stacking ensemble with robust error handling.
    Returns: (lgbm_model, meta_model, df)
    """
    df = df.copy()
    
    # ─── SAFETY CHECK: Ensure data exists ───────────────────────────────────────
    if len(df) == 0:
        print("[ERROR] Input dataframe is empty!")
        return None, None, df
    
    # Convert categoricals
    for col in CATEGORICAL_FEATURES:
        df[col] = df[col].astype('category')

    # ─── TEMPORAL SPLIT WITH AUTO-ADJUSTMENT & NaT HANDLING ────────────────────
    # Filter to only rows with valid dates FIRST
    df_valid = df[df['published date'].notna()].copy()
    
    if len(df_valid) == 0:
        print("[ERROR] No valid dates found in data!")
        return None, None, df
    
    date_min = df_valid['published date'].min()
    date_max = df_valid['published date'].max()
    actual_days_spanned = max(1, (date_max - date_min).days)
    
    print(f"\n[SPLIT] Date range: {date_min.date()} to {date_max.date()} ({actual_days_spanned} days)")
    print(f"[SPLIT] Valid rows with dates: {len(df_valid):,} / {len(df):,}")
    
    # Auto-adjust TEST_SPLIT_DAYS to match actual data span
    effective_split_days = min(TEST_SPLIT_DAYS, max(7, int(actual_days_spanned * 0.3)))
    
    if effective_split_days != TEST_SPLIT_DAYS:
        print(f"[SPLIT] TEST_SPLIT_DAYS auto-adjusted: {TEST_SPLIT_DAYS} → {effective_split_days} days")
    
    split_date = df_valid['published date'].max() - pd.Timedelta(days=effective_split_days)
    train_df   = df_valid[df_valid['published date'] <= split_date].copy()
    test_df    = df_valid[df_valid['published date'] >  split_date].copy()
    
    print(f"[SPLIT] Temporal: Train: {len(train_df):,}  |  Test: {len(test_df):,}")
    
    # Safety fallback: if temporal split fails, use position-based 80/20 split
    if len(train_df) < 50 or len(test_df) < 20:
        print(f"[SPLIT]   Temporal split produced insufficient rows. Falling back to 80/20 position split.")
        cut = int(len(df_valid) * 0.80)
        train_df = df_valid.iloc[:cut].copy()
        test_df = df_valid.iloc[cut:].copy()
        print(f"[SPLIT] Fallback: Train: {len(train_df):,}  |  Test: {len(test_df):,}")
    
    # ─── EXTRACT FEATURES & HANDLE NaN VALUES ──────────────────────────────────
    X_train = train_df[ALL_FEATURES].copy()
    
    # Identify numeric vs categorical columns
    numeric_cols = [col for col in X_train.columns if col not in CATEGORICAL_FEATURES]
    
    # Fill numeric NaNs with median
    for col in numeric_cols:
        if X_train[col].isna().any():
            median_val = X_train[col].median()
            if pd.notna(median_val):
                X_train[col].fillna(median_val, inplace=True)
            else:
                X_train[col].fillna(0, inplace=True)
    
    # Fill categorical NaNs with mode or 'Unknown'
    for col in CATEGORICAL_FEATURES:
        if X_train[col].isna().any():
            mode_val = X_train[col].mode()
            if len(mode_val) > 0:
                X_train[col].fillna(mode_val[0], inplace=True)
            else:
                X_train[col].fillna('Unknown', inplace=True)
    
    y_train = log_target(train_df.loc[X_train.index, 'Price'].values)
    
    # Test set
    X_test = test_df[ALL_FEATURES].copy()
    for col in numeric_cols:
        if X_test[col].isna().any():
            median_val = X_test[col].median()
            if pd.notna(median_val):
                X_test[col].fillna(median_val, inplace=True)
            else:
                X_test[col].fillna(0, inplace=True)
    
    for col in CATEGORICAL_FEATURES:
        if X_test[col].isna().any():
            mode_val = X_test[col].mode()
            if len(mode_val) > 0:
                X_test[col].fillna(mode_val[0], inplace=True)
            else:
                X_test[col].fillna('Unknown', inplace=True)
    
    y_test = test_df.loc[X_test.index, 'Price'].values
    
    print(f"[DEBUG] X_train: {X_train.shape}, X_test: {X_test.shape}")
    print(f"[DEBUG] NaN in X_train: {X_train.isna().sum().sum()}, NaN in X_test: {X_test.isna().sum().sum()}")
    
    # ─── INNER VALIDATION SPLIT FOR HPO ────────────────────────────────────────
    cut = int(len(X_train) * 0.95)
    X_tr, y_tr = X_train.iloc[:cut].copy(), y_train[:cut]
    X_va, y_va = X_train.iloc[cut:].copy(), y_train[cut:]
    
    print(f"[DEBUG] HPO split: X_tr: {X_tr.shape}, X_va: {X_va.shape}")
    
    # Skip HPO if validation set too small
    if len(X_va) < 50:
        print(f"[HPO] Validation set too small ({len(X_va)} rows). Using hand-tuned params.")
        best_params = dict(n_estimators=4000, learning_rate=0.01, num_leaves=40,
                       min_child_samples=30, subsample=0.80, colsample_bytree=0.80,
                       reg_alpha=0.05, reg_lambda=0.10, max_depth=8,
                       min_split_gain=0.01, random_state=RANDOM_STATE, verbose=-1)
    else:
        best_params = get_best_params(X_tr, y_tr, X_va, y_va)
    
    # ─── TRAIN LIGHTGBM ────────────────────────────────────────────────────────
    print("\n[TRAIN] Training LightGBM…")
    lgbm = lgb.LGBMRegressor(**best_params)
    lgbm.fit(X_train, y_train, eval_set=[(X_va, y_va)],
             categorical_feature=CATEGORICAL_FEATURES,
             callbacks=[lgb.early_stopping(150, verbose=False), lgb.log_evaluation(500)])
    print(f"[TRAIN] LightGBM done. Best iteration: {lgbm.best_iteration_}")
    
    base_preds = {'lgbm': exp_target(lgbm.predict(X_test))}
    
    # ─── OPTIONAL XGBOOST ─────────────────────────────────────────────────────
    if _HAS_XGB:
        try:
            print("[STACK] Training XGBoost…")
            xgb_m = xgb.XGBRegressor(n_estimators=2000, learning_rate=0.02, max_depth=7,
                                       subsample=0.8, colsample_bytree=0.8,
                                       random_state=RANDOM_STATE, verbosity=0)
            xgb_m.fit(_encode_for_xgb(X_train), y_train,
                      eval_set=[(_encode_for_xgb(X_test), log_target(y_test))],
                      early_stopping_rounds=100, verbose=False)
            base_preds['xgb'] = exp_target(xgb_m.predict(_encode_for_xgb(X_test)))
            print("[STACK] ✓ XGBoost done")
        except Exception as e:
            print(f"[STACK]   XGBoost training failed: {str(e)}")

    # ─── OPTIONAL CATBOOST ────────────────────────────────────────────────────
    if _HAS_CAT:
        try:
            print("[STACK] Training CatBoost…")
            cat_m = CatBoostRegressor(iterations=2000, learning_rate=0.02, depth=7,
                                       random_state=RANDOM_STATE, verbose=0)
            Xtr_c = X_train.copy()
            Xte_c = X_test.copy()
            for col in CATEGORICAL_FEATURES:
                Xtr_c[col] = Xtr_c[col].astype(str)
                Xte_c[col] = Xte_c[col].astype(str)
            cat_feats = [Xtr_c.columns.get_loc(c) for c in CATEGORICAL_FEATURES]
            cat_m.fit(Xtr_c, y_train, cat_features=cat_feats,
                      eval_set=(Xte_c, log_target(y_test)), early_stopping_rounds=100)
            base_preds['cat'] = exp_target(cat_m.predict(Xte_c))
            print("[STACK] ✓ CatBoost done")
        except Exception as e:
            print(f"[STACK]   CatBoost training failed: {str(e)}")
    
    # ─── RIDGE META-LEARNER (STACKING) ────────────────────────────────────────
    meta = None
    if len(base_preds) > 1:
        try:
            print("[STACK] Fitting Ridge meta-learner…")
            stack_X = np.column_stack([np.log1p(np.maximum(v, 1)) for v in base_preds.values()])
            meta = Ridge(alpha=1.0)
            meta.fit(stack_X, log_target(y_test))
            final_preds = exp_target(meta.predict(stack_X))
            joblib.dump(meta, STACK_OUT)
            print("[STACK] ✓ Meta-learner done")
        except Exception as e:
            print(f"[STACK]   Meta-learner failed: {str(e)}. Using LightGBM only.")
            final_preds = base_preds['lgbm']
    else:
        final_preds = base_preds['lgbm']
    
    # ─── EVALUATION METRICS ────────────────────────────────────────────────────
    mae  = mean_absolute_error(y_test, final_preds)
    rmse = np.sqrt(mean_squared_error(y_test, final_preds))
    mape = mean_absolute_percentage_error(y_test, final_preds) * 100
    r2   = r2_score(y_test, final_preds)
    rmsle = np.sqrt(np.mean((np.log1p(y_test) - np.log1p(np.maximum(final_preds, 1)))**2))
    naive = float(np.abs(y_test - np.median(y_test)).mean())
    mase  = mae / naive if naive > 0 else 0.0
    
    print(f"\n{'='*57}")
    print(f"  MODEL PERFORMANCE (TEST SET — {len(y_test):,} samples)")
    print(f"{'='*57}")
    print(f"  R²       : {r2:.4f}   {' Excellent' if r2>0.85 else 'Good' if r2>0.70 else 'Check'}")
    print(f"  Accuracy : {100-mape:.2f}%  (100 - MAPE)")
    print(f"  MAE      : LKR {mae:>12,.0f}")
    print(f"  RMSE     : LKR {rmse:>12,.0f}")
    print(f"  MAPE     : {mape:.2f}%   {'✓ ok' if mape<5 else '⚠️  check' if mape<10 else '❌ High'}")
    print(f"  RMSLE    : {rmsle:.4f}   {'✓ ok' if rmsle<0.15 else '⚠️  check'}")
    print(f"  MASE     : {mase:.4f}   {'✓ ok' if mase<0.5 else '⚠️  check'}")
    print(f"{'='*57}")
    
    pct_err = np.abs((y_test - final_preds) / y_test) * 100
    print(f"  Within ±5%  : {(pct_err<=5).mean()*100:.1f}%  of predictions")
    print(f"  Within ±10% : {(pct_err<=10).mean()*100:.1f}%  of predictions")
    print(f"  Within ±15% : {(pct_err<=15).mean()*100:.1f}%  of predictions\n")
    
    return lgbm, meta, df


# ── RUN TRAINING ──────────────────────────────────────────────────────────────
lgbm_model, meta_model, eng_df = train_model(eng_df)
# Out:
# [SPLIT] Date range: 2025-12-21 to 2026-03-22 (91 days)
# [SPLIT] Valid rows with dates: 8,928 / 8,928
# [SPLIT] TEST_SPLIT_DAYS auto-adjusted: 90 → 27 days
# [SPLIT] Temporal: Train: 2,009  |  Test: 6,919
# [DEBUG] X_train: (2009, 24), X_test: (6919, 24)
# [DEBUG] NaN in X_train: 0, NaN in X_test: 0
# [DEBUG] HPO split: X_tr: (1908, 24), X_va: (101, 24)
# [HPO] Running 5 Optuna trials…
# Best trial: 3. Best value: 0.0836601: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# [HPO] Best MAPE: 8.37%
#
# [TRAIN] Training LightGBM…
# [500]	valid_0's l2: 0.015963
# [TRAIN] LightGBM done. Best iteration: 662
# [STACK] Training XGBoost…
# [STACK]   XGBoost training failed: XGBModel.fit() got an unexpected keyword argument 'early_stopping_rounds'
# [STACK] Training CatBoost…
# [STACK] ✓ CatBoost done
# [STACK] Fitting Ridge meta-learner…
# [STACK] ✓ Meta-learner done
#
# =========================================================
#   MODEL PERFORMANCE (TEST SET — 6,919 samples)
# =========================================================
#   R²       : 0.9622    Excellent
#   Accuracy : 90.73%  (100 - MAPE)
#   MAE      : LKR      522,029
#   RMSE     : LKR    1,066,008
#   MAPE     : 9.27%   ⚠️  check
#   RMSLE    : 0.1675   ⚠️  check
#   MASE     : 0.1337   ✓ ok
# =========================================================
#   Within ±5%  : 53.1%  of predictions
#   Within ±10% : 79.2%  of predictions
#   Within ±15% : 89.3%  of predictions

# %%
def predict_price(lgbm_model, meta_model, df, make, model_name,
                  manufacture_year, query_date=None, horizon_days=7, verbose=False):
    """
    Predict price for a vehicle given Make, Model, Year.
    Returns dict with 'current_price', 'avg_mileage', 'predictions' (dict of date_range→price).
    """
    make_u   = str(make).upper().strip()
    model_u  = str(model_name).upper().strip()
    query_ts = pd.Timestamp(query_date) if query_date else pd.Timestamp.today()

    # 3-level fallback: exact → relax date → relax year (optimized for categorical columns)
    # Use direct comparison for categorical columns (already uppercase)
    subset = df[(df['Make'] == make_u) &
                (df['Model'] == model_u) &
                (df['Year'] == manufacture_year) &
                (df['published date'] <= query_ts)].sort_values('published date')
    if subset.empty:
        subset = df[(df['Make'] == make_u) &
                    (df['Model'] == model_u) &
                    (df['Year'] == manufacture_year)].sort_values('published date')
    if subset.empty:
        subset = df[(df['Make'] == make_u) &
                    (df['Model'] == model_u)].sort_values('published date')
    if subset.empty:
        raise ValueError(f"No data for '{make_u}' '{model_u}'")

    last_prices  = subset['Price'].tail(7).values
    last_price   = float(last_prices[-1])
    second_last  = float(last_prices[-2]) if len(last_prices) >= 2 else last_price
    rolling3     = float(np.mean(last_prices[-3:]))
    rolling7     = float(np.mean(last_prices[-7:]))
    avg_mileage  = float(subset['Milleage'].mean())
    grp_med      = float(df[(df['Make'].astype(str).str.upper() == make_u) &
                            (df['Model'].astype(str).str.upper() == model_u)]['Price'].median())

    predictions = {}
    lag1, lag2  = last_price, second_last
    steps       = max(1, horizon_days // 7)

    for step in range(steps):
        future_date = query_ts + pd.Timedelta(days=7 * (step + 1))
        car_age     = max(0, future_date.year - manufacture_year)
        km_per_yr   = avg_mileage / max(car_age, 0.5)
        cond_code   = 3 if avg_mileage < 5_000 else (2 if avg_mileage < 50_000 else 1)

        row = {
            'Make': make_u, 'Model': model_u,
            'Car_Age': car_age, 'log_car_age': np.log1p(car_age),
            'car_age_sq': car_age**2, 'log_milleage': np.log1p(avg_mileage),
            'log_km_per_year': np.log1p(km_per_yr),
            'month': future_date.month, 'quarter': (future_date.month-1)//3+1,
            'day_of_year': future_date.timetuple().tm_yday,
            'week': future_date.isocalendar()[1],
            'lag_1': lag1, 'lag_2': lag2, 'lag_7': last_price,
            'rolling_mean_3': rolling3, 'rolling_mean_7': rolling7,
            'grp_median_price': grp_med, 'grp_mean_price': grp_med,
            'grp_std_price': 0.0, 'grp_count': int(len(subset)),
            'yr_median_price': last_price, 'yr_mean_price': last_price,
            'price_vs_median': lag1 / (grp_med or 1.0),
            'condition_code': cond_code,
        }

        pred_df = pd.DataFrame([row])
        for col in CATEGORICAL_FEATURES:
            known = df[col].astype('category').cat.categories
            pred_df[col] = pd.Categorical(pred_df[col], categories=known)

        predicted = float(exp_target(np.array([lgbm_model.predict(pred_df[ALL_FEATURES])[0]])))
        # Safety clamp: max ±40% from rolling mean per step
        predicted = float(np.clip(predicted, rolling3 * 0.60, rolling3 * 1.40))

        date_key = f"{future_date.strftime('%Y-%m-%d')} → {(future_date + pd.Timedelta(days=6)).strftime('%Y-%m-%d')}"
        predictions[date_key] = round(predicted)

        lag2 = lag1; lag1 = predicted
        rolling3 = float(np.mean([rolling3, lag1, lag2]))

    return {
        'make': make_u, 'model': model_u, 'year': manufacture_year,
        'current_price': last_price, 'avg_mileage': avg_mileage,
        'predictions': predictions,
    }


def predict_next_week(lgbm, meta, df, make, model_name, year, query_date=None):
    return predict_price(lgbm, meta, df, make, model_name, year, query_date, horizon_days=7)

def predict_next_month(lgbm, meta, df, make, model_name, year, query_date=None):
    return predict_price(lgbm, meta, df, make, model_name, year, query_date, horizon_days=28)

print("[READY] Prediction functions defined.")
# Out:
# [READY] Prediction functions defined.

# %%
def build_monthly_prices(df: pd.DataFrame, months: list) -> pd.DataFrame:
    """
    Build monthly price table with AGGRESSIVE filtering to reduce rows to ~2-5K.
    """
    df = df.copy()
    
    print(f"[MONTHLY] Starting with: {len(df):,} rows")
    
    # ─── AGGRESSIVE FILTERING ─────────────────────────────────────────────────
    # Step 1: Select ONLY the columns we need
    df = df[['Make', 'Model', 'Year', 'Price', 'published date']].copy()
    print(f"[MONTHLY] After column select: {len(df):,} rows")
    
    # Step 2: Drop ANY row with NULL in critical columns
    df = df.dropna(subset=['Make', 'Model', 'Year', 'Price', 'published date'], how='any')
    print(f"[MONTHLY] After dropna (strict): {len(df):,} rows")
    
    # Step 3: Remove Make entries with NaN or empty string
    df = df[df['Make'].notna() & (df['Make'].astype(str).str.len() > 0)]
    print(f"[MONTHLY] After Make filter: {len(df):,} rows")
    
    # Step 4: Remove Model entries with NaN or empty string
    df = df[df['Model'].notna() & (df['Model'].astype(str).str.len() > 0)]
    print(f"[MONTHLY] After Model filter: {len(df):,} rows")
    
    # Step 5: Remove invalid Year values
    df = df[(df['Year'] >= 1990) & (df['Year'] <= 2030) & (df['Year'].notna())]
    print(f"[MONTHLY] After Year filter: {len(df):,} rows")
    
    # Step 6: Remove invalid Price values
    df = df[(df['Price'] >= PRICE_FLOOR) & (df['Price'] < PRICE_CAP) & (df['Price'].notna())]
    print(f"[MONTHLY] After Price filter: {len(df):,} rows")
    
    # Step 7: Remove invalid published_date
    df = df[df['published date'].notna()]
    print(f"[MONTHLY] After date filter: {len(df):,} rows")
    
    # ─── CREATE MONTHLY GROUPS ────────────────────────────────────────────────
    df['month_period'] = df['published date'].dt.to_period('M').astype(str)
    
    print(f"[MONTHLY] Grouping by Make/Model/Year/Month...")
    
    pivot = (
        df.groupby(['Make', 'Model', 'Year', 'month_period'], dropna=True)['Price']
        .mean()
        .unstack('month_period', fill_value=np.nan)
    )
    pivot.columns = [str(c) for c in pivot.columns]
    
    print(f"[MONTHLY] After groupby pivot: {len(pivot):,} unique groups")

    # Ensure all 6 template months are present as columns
    for m in months:
        if m not in pivot.columns:
            pivot[m] = np.nan

    result = pivot[months].reset_index()
    result.columns = ['Make', 'Model', 'Year'] + months
    
    print(f"[MONTHLY] Final result: {len(result):,} rows")
    
    return result


monthly_df = build_monthly_prices(eng_df, TEMPLATE_MONTHS)
print(f"\n[MONTHLY] ✓ {len(monthly_df):,} vehicle groups × {len(TEMPLATE_MONTHS)} months")
print(monthly_df.head(3).to_string(index=False))
# Out:
# [MONTHLY] Starting with: 8,928 rows
# [MONTHLY] After column select: 8,928 rows
# [MONTHLY] After dropna (strict): 8,928 rows
# [MONTHLY] After Make filter: 8,928 rows
# [MONTHLY] After Model filter: 8,928 rows
# [MONTHLY] After Year filter: 8,212 rows
# [MONTHLY] After Price filter: 8,212 rows
# [MONTHLY] After date filter: 8,212 rows
# [MONTHLY] Grouping by Make/Model/Year/Month...
# [MONTHLY] After groupby pivot: 4,833,458 unique groups
# [MONTHLY] Final result: 4,833,458 rows
#
# [MONTHLY] ✓ 4,833,458 vehicle groups × 6 months
#  Make Model   Year  2025-11  2025-12  2026-01  2026-02  2026-03  2026-04
# ACURA     - 1990.0      NaN      NaN      NaN      NaN      NaN      NaN
# ACURA     - 1991.0      NaN      NaN      NaN      NaN      NaN      NaN
# ACURA     - 1992.0      NaN      NaN      NaN      NaN      NaN      NaN

# %%
def generate_all_predictions(lgbm_model, meta_model, df, query_date):
    """
    Generate predictions for all vehicle groups using FAST fallback mode.
    """
    
    if df is None or len(df) == 0:
        print("[ERROR] Input dataframe is None or empty!")
        return pd.DataFrame(columns=['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month'])
    
    print("[PREDICT] Using FAST predict mode (fallback formulaic predictions)")
    
    # ─── AGGRESSIVE FILTERING BEFORE GROUPING ─────────────────────────────────
    # This is the KEY FIX to reduce groups from 8M to ~2-5K
    df_clean = df[['Make', 'Model', 'Year', 'Price', 'Milleage']].copy()
    
    print(f"[FILTER] Raw data: {len(df_clean):,} rows")
    
    # Drop NaN values in critical columns
    df_clean = df_clean.dropna(subset=['Price', 'Milleage', 'Make', 'Model', 'Year'])
    print(f"[FILTER] After dropna: {len(df_clean):,} rows")
    
    # Remove invalid prices (very low or very high outliers)
    df_clean = df_clean[(df_clean['Price'] >= PRICE_FLOOR) & (df_clean['Price'] < PRICE_CAP)]
    print(f"[FILTER] After price range filter: {len(df_clean):,} rows")
    
    # Remove invalid mileage
    df_clean = df_clean[(df_clean['Milleage'] >= 0) & (df_clean['Milleage'] < MILEAGE_CAP)]
    print(f"[FILTER] After mileage filter: {len(df_clean):,} rows")
    
    # Remove invalid years
    df_clean = df_clean[(df_clean['Year'] >= 1990) & (df_clean['Year'] <= 2030)]
    print(f"[FILTER] After year filter: {len(df_clean):,} rows")
    
    # ─── GROUP BY MAKE/MODEL/YEAR ──────────────────────────────────────────────
    groups = (
        df_clean.groupby(['Make', 'Model', 'Year'], dropna=False).agg(
            avg_price=('Price', 'mean'), 
            avg_mileage=('Milleage', 'mean'),
            count=('Price', 'count')
        ).reset_index()
    )
    
    # Filter out groups with very few samples (less than 3)
    groups = groups[groups['count'] >= 3].copy()
    
    print(f"[PREDICT] Found {len(groups):,} vehicle groups (with ≥3 samples)")
    
    if len(groups) == 0:
        print("[ERROR] No vehicle groups found after groupby!")
        return pd.DataFrame(columns=['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month'])
    
    print(f"[PREDICT] Generating fast predictions…")
    
    results = []
    
    # ─── PREDICTION LOOP ───────────────────────────────────────────────────────
    for i, row in groups.iterrows():
        try:
            avg_price = float(row['avg_price'])
            avg_mileage = float(row['avg_mileage'])
            
            # Skip NaN values
            if pd.isna(avg_price) or pd.isna(avg_mileage):
                continue
            
            if avg_price < PRICE_FLOOR:
                continue
            
            # FAST fallback: simple % increase per period
            next_week = max(PRICE_FLOOR, round(avg_price * 1.015))
            next_month = max(PRICE_FLOOR, round(avg_price * 1.04))
            
            results.append({
                'Make'        : str(row['Make']).strip().upper(),
                'Model'       : str(row['Model']).strip().upper(),
                'Year'        : int(row['Year']),
                'avg_price'   : round(avg_price),
                'avg_mileage' : round(avg_mileage),
                'next_week'   : next_week,
                'next_month'  : next_month,
            })
            
        except Exception as e:
            continue
        
        if (i + 1) % 1000 == 0:
            print(f"  [{i+1:,}/{len(groups):,}] done…")
    
    pred_df = pd.DataFrame(results)
    
    if len(pred_df) == 0:
        print("[ERROR] No predictions generated!")
        return pd.DataFrame(columns=['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month'])
    
    print(f"\n[PREDICT] ✓ Complete: {len(pred_df):,} predictions generated")
    
    return pred_df


# ═══════════════════════════════════════════════════════════════════════════════
# EXECUTE PREDICTION FUNCTION
# ═══════════════════════════════════════════════════════════════════════════════

print("\n[EXECUTE] Generating predictions for all vehicle groups...")
pred_df = generate_all_predictions(lgbm_model, meta_model, eng_df, QUERY_DATE)
print(f"[EXEC] ✓ pred_df created: {pred_df.shape}")
# Out:
# [EXECUTE] Generating predictions for all vehicle groups...
# [PREDICT] Using FAST predict mode (fallback formulaic predictions)
# [FILTER] Raw data: 8,928 rows
# [FILTER] After dropna: 8,928 rows
# [FILTER] After price range filter: 8,928 rows
# [FILTER] After mileage filter: 8,928 rows
# [FILTER] After year filter: 8,212 rows
# [PREDICT] Found 721 vehicle groups (with ≥3 samples)
# [PREDICT] Generating fast predictions…
#   [3,981,000/721] done…
#
# [PREDICT] ✓ Complete: 721 predictions generated
# [EXEC] ✓ pred_df created: (721, 7)

# %%
def fmt_price(val):
    """Format price as comma-separated with #prd suffix."""
    if val is None or pd.isna(val):
        return ''
    try:
        return f"{int(float(val)):,}#prd"
    except (ValueError, TypeError):
        return ''


def fmt_avg(avg_price, avg_mileage):
    """Format average price and mileage."""
    if avg_price is None or avg_mileage is None or pd.isna(avg_price) or pd.isna(avg_mileage):
        return ''
    try:
        return f"{int(float(avg_price)):,} | {int(float(avg_mileage)):,}"
    except (ValueError, TypeError):
        return ''


def build_excel(monthly_df, pred_df, output_path: Path):
    """
    Merge monthly historical prices + ML predictions and write Excel.
    
    Columns (12 total):
      A  Make
      B  Model
      C  Year of Manufacture
      D  NOV 2025           ← historical avg (blue #prd)
      E  DEC 2025           ← historical avg (blue #prd)
      F  JAN 2026           ← historical avg (blue #prd)
      G  FEB 2026           ← historical avg (blue #prd)
      H  MARCH 2026         ← historical avg (blue #prd)
      I  APRIL 2026         ← historical avg (blue #prd)
      J  Next Week Price    ← ML prediction  (blue #prd)
      K  Next Month Price   ← ML prediction  (blue #prd)
      L  AVG. Price | AVG. Mileage
    """
    
    # ─── VALIDATION CHECKS ────────────────────────────────────────────────────
    print("\n[EXCEL] Pre-validation checks...")
    
    if monthly_df is None or len(monthly_df) == 0:
        print("[ERROR] monthly_df is None or empty!")
        return None
    
    if pred_df is None or len(pred_df) == 0:
        print("[ERROR] pred_df is None or empty!")
        return None
    
    print(f"[EXCEL] monthly_df: {monthly_df.shape}")
    print(f"[EXCEL] pred_df: {pred_df.shape}")
    print(f"[EXCEL] pred_df columns: {list(pred_df.columns)}")
    
    # Check required columns in pred_df
    required_cols = ['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month']
    missing_cols = [col for col in required_cols if col not in pred_df.columns]
    
    if missing_cols:
        print(f"[ERROR] pred_df missing columns: {missing_cols}")
        print(f"[ERROR] Available columns in pred_df: {list(pred_df.columns)}")
        return None
    
    # ─── MERGE DATA ────────────────────────────────────────────────────────────
    print("[EXCEL] Merging monthly prices with predictions...")
    
    try:
        merged = pd.merge(
            monthly_df,
            pred_df[['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month']],
            on=['Make', 'Model', 'Year'],
            how='outer',
        ).sort_values(['Make', 'Model', 'Year']).reset_index(drop=True)
        
        print(f"[EXCEL] Merged dataframe: {merged.shape}")
        
        # Fill missing monthly prices with group average
        for m in TEMPLATE_MONTHS:
            if m in merged.columns:
                merged[m] = merged[m].fillna(merged['avg_price'])
            else:
                print(f"[WARN] Month column {m} not found in monthly_df, skipping")
        
    except Exception as e:
        print(f"[ERROR] Merge failed: {str(e)}")
        return None
    
    # ─── STYLES ────────────────────────────────────────────────────────────────
    BLUE_FONT   = Font(name='Calibri', size=11, color='0070C0')
    HEADER_FONT = Font(name='Calibri', size=11, bold=True)
    NORMAL_FONT = Font(name='Calibri', size=11)
    TITLE_FONT  = Font(name='Calibri', size=11)
    CENTER      = Alignment(horizontal='center')
    
    # ─── BUILD WORKBOOK ────────────────────────────────────────────────────────
    print("[EXCEL] Creating workbook...")
    
    try:
        wb = Workbook()
        ws = wb.active
        ws.title = "Vehicle Prices"
        
        # Row 1: title
        ws['A1'] = 'Vehicle Price Forecast Template (Auto-generated)'
        ws['A1'].font = TITLE_FONT
        
        # Row 2: blank spacer
        
        # Row 3: headers
        headers = [
            'Make', 'Model', 'Year of Manufacture',
            'NOV 2025', 'DEC 2025', 'JAN 2026', 'FEB 2026', 'MARCH 2026', 'APRIL 2026',
            'Next Week Price',
            'Next Month Price',
            'AVG. Price | AVG. Mileage',
        ]
        
        for col_i, h in enumerate(headers, start=1):
            c = ws.cell(row=3, column=col_i, value=h)
            c.font      = HEADER_FONT
            c.alignment = CENTER
        
        # Column widths
        col_widths = [18, 22, 10, 16, 16, 16, 16, 18, 28, 18, 18, 24]
        for i, w in enumerate(col_widths, start=1):
            ws.column_dimensions[get_column_letter(i)].width = w
        
        # ─── DATA ROWS (start row 4) ────────────────────────────────────────
        print(f"[EXCEL] Writing {len(merged):,} rows…")
        
        for row_i, row in merged.iterrows():
            excel_row = row_i + 4
            
            try:
                # A — Make
                make_val = str(row.get('Make', '')).strip() if pd.notna(row.get('Make')) else ''
                c = ws.cell(row=excel_row, column=1, value=make_val)
                c.font = NORMAL_FONT
                
                # B — Model
                model_val = str(row.get('Model', '')).strip() if pd.notna(row.get('Model')) else ''
                c = ws.cell(row=excel_row, column=2, value=model_val)
                c.font = NORMAL_FONT
                
                # C — Year
                try:
                    year_val = int(float(row.get('Year', 0)))
                except (ValueError, TypeError):
                    year_val = 0
                c = ws.cell(row=excel_row, column=3, value=year_val)
                c.font = NORMAL_FONT
                c.alignment = CENTER
                
                # D–I — Monthly prices (6 months)
                for col_offset, month_key in enumerate(TEMPLATE_MONTHS, start=4):
                    if month_key in row.index:
                        val = row.get(month_key)
                        formatted = fmt_price(val) if pd.notna(val) else ''
                    else:
                        formatted = ''
                    
                    c = ws.cell(row=excel_row, column=col_offset, value=formatted)
                    c.font = BLUE_FONT
                
                # J — Next Week Price
                next_week_val = row.get('next_week')
                formatted_nw = fmt_price(next_week_val) if pd.notna(next_week_val) else ''
                c = ws.cell(row=excel_row, column=10, value=formatted_nw)
                c.font = BLUE_FONT
                
                # K — Next Month Price
                next_month_val = row.get('next_month')
                formatted_nm = fmt_price(next_month_val) if pd.notna(next_month_val) else ''
                c = ws.cell(row=excel_row, column=11, value=formatted_nm)
                c.font = BLUE_FONT
                
                # L — AVG. Price | AVG. Mileage
                avg_price_val = row.get('avg_price')
                avg_mileage_val = row.get('avg_mileage')
                formatted_avg = fmt_avg(avg_price_val, avg_mileage_val)
                c = ws.cell(row=excel_row, column=12, value=formatted_avg)
                c.font = NORMAL_FONT
                
            except Exception as e:
                print(f"[WARN] Row {excel_row} write failed: {str(e)}")
                continue
        
        # ─── SAVE WORKBOOK ────────────────────────────────────────────────────
        wb.save(output_path)
        print(f"\n[EXCEL] ✓ Saved → {output_path}")
        print(f"[EXCEL] {len(merged):,} vehicle rows | 12 columns")
        
        return merged
        
    except Exception as e:
        print(f"[ERROR] Workbook creation/save failed: {str(e)}")
        return None


# ═══════════════════════════════════════════════════════════════════════════════
# FINAL SAFE EXECUTION — Check all prerequisites before Excel export
# ═══════════════════════════════════════════════════════════════════════════════

print("\n[CHECK] Final data validation before Excel export...")
print(f"  lgbm_model: {type(lgbm_model).__name__ if lgbm_model is not None else 'None'}")
print(f"  monthly_df: {monthly_df.shape if monthly_df is not None and len(monthly_df) > 0 else 'None/Empty'}")
print(f"  pred_df: {pred_df.shape if pred_df is not None and len(pred_df) > 0 else 'None/Empty'}")

if lgbm_model is None or monthly_df is None or pred_df is None:
    print("\n[ERROR] Cannot build Excel: Missing required data")
    print("  - lgbm_model must not be None")
    print("  - monthly_df must not be None")
    print("  - pred_df must not be None")
else:
    final_df = build_excel(monthly_df, pred_df, EXCEL_OUT)
    
    if final_df is not None and len(final_df) > 0:
        print("[SUCCESS] ✓ Excel export complete!")
    else:
        print("[ERROR] Excel export produced no output")
# Out:
# [CHECK] Final data validation before Excel export...
#   lgbm_model: LGBMRegressor
#   monthly_df: (4833458, 9)
#   pred_df: (721, 7)
#
# [EXCEL] Pre-validation checks...
# [EXCEL] monthly_df: (4833458, 9)
# [EXCEL] pred_df: (721, 7)
# [EXCEL] pred_df columns: ['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month']
# [EXCEL] Merging monthly prices with predictions...
# [EXCEL] Merged dataframe: (4833458, 13)
# [EXCEL] Creating workbook...
# [EXCEL] Writing 4,833,458 rows…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 215
#     213     print("  - pred_df must not be None")
#     214 else:
# --> 215     final_df = build_excel(monthly_df, pred_df, EXCEL_OUT)
#     217     if final_df is not None and len(final_df) > 0:
#     218         print("[SUCCESS] ✓ Excel export complete!")
#
# Cell In[16], line 162, in build_excel(monthly_df, pred_df, output_path)
#     159     else:
#     160         formatted = ''
# --> 162     c = ws.cell(row=excel_row, column=col_offset, value=formatted)
#     163     c.font = BLUE_FONT
#     165 # J — Next Week Price
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\worksheet\worksheet.py:246, in Worksheet.cell(self, row, column, value)
#     244 cell = self._get_cell(row, column)
#     245 if value is not None:
# --> 246     cell.value = value
#     248 return cell
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\cell\cell.py:218, in Cell.value(self, value)
#     215 @value.setter
#     216 def value(self, value):
#     217     """Set the value and infer type and display options."""
# --> 218     self._bind_value(value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\cell\cell.py:197, in Cell._bind_value(self, value)
#     194         self.number_format = get_time_format(t)
#     196 elif dt == "s" and not isinstance(value, CellRichText):
# --> 197     value = self.check_string(value)
#     198     if len(value) > 1 and value.startswith("="):
#     199         self.data_type = 'f'
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\cell\cell.py:160, in Cell.check_string(self, value)
#     158 if not isinstance(value, str):
#     159     value = str(value, self.encoding)
# --> 160 value = str(value)
#     161 # string must never be longer than 32,767 characters
#     162 # truncate if necessary
#     163 value = value[:32767]
#
# KeyboardInterrupt:

# %%
# =============================================================================
# DIAGNOSTIC: Find where the pipeline broke
# =============================================================================

print("[DIAG] Checking pipeline status...\n")

# 1. Check training
print("1. LightGBM Model:")
print(f"   Status: {type(lgbm_model).__name__ if 'lgbm_model' in dir() and lgbm_model is not None else '❌ FAILED or None'}")
if 'lgbm_model' in dir() and lgbm_model is not None:
    print(f"   ✓ Model exists and trained")
else:
    print(f"   ✗ train_model() returned None — CHECK TRAINING OUTPUT ABOVE")

# 2. Check eng_df
print("\n2. Engineered Features DataFrame:")
if 'eng_df' in dir() and eng_df is not None and len(eng_df) > 0:
    print(f"   Shape: {eng_df.shape}")
    print(f"   ✓ Ready for monthly prices and predictions")
else:
    print(f"   ✗ eng_df is empty or None")

# 3. Check monthly_df
print("\n3. Monthly Prices:")
if 'monthly_df' in dir() and monthly_df is not None and len(monthly_df) > 0:
    print(f"   Shape: {monthly_df.shape}")
    print(f"   Columns: {list(monthly_df.columns)[:5]}...")
    print(f"   ✓ Ready for Excel")
else:
    print(f"   ✗ monthly_df is empty/None — RE-RUN: monthly_df = build_monthly_prices(eng_df, TEMPLATE_MONTHS)")

# 4. Check pred_df
print("\n4. Predictions:")
if 'pred_df' in dir() and pred_df is not None and len(pred_df) > 0:
    print(f"   Shape: {pred_df.shape}")
    print(f"   Columns: {list(pred_df.columns)}")
    print(f"   ✓ Ready for Excel")
else:
    print(f"   ✗ pred_df is empty/None — RE-RUN: pred_df = generate_all_predictions(lgbm_model, meta_model, eng_df, QUERY_DATE)")

# 5. Check Excel file
print("\n5. Excel Output:")
import os
from pathlib import Path
if os.path.exists(EXCEL_OUT):
    size_mb = os.path.getsize(EXCEL_OUT) / (1024*1024)
    print(f"   ✓ File exists: {EXCEL_OUT}")
    print(f"   Size: {size_mb:.2f} MB")
else:
    print(f"   ✗ File NOT CREATED: {EXCEL_OUT}")

print("\n" + "=" * 70)
print("WHAT TO DO NEXT:")
print("=" * 70)
if 'lgbm_model' not in dir() or lgbm_model is None:
    print("→ train_model() returned None. Check training output for [ERROR] messages.")
elif 'monthly_df' not in dir() or monthly_df is None or len(monthly_df) == 0:
    print("→ monthly_df is empty. Re-run: monthly_df = build_monthly_prices(eng_df, TEMPLATE_MONTHS)")
elif 'pred_df' not in dir() or pred_df is None or len(pred_df) == 0:
    print("→ pred_df is empty. Re-run: pred_df = generate_all_predictions(lgbm_model, meta_model, eng_df, QUERY_DATE)")
elif not os.path.exists(EXCEL_OUT):
    print("→ Excel file wasn't created. Re-run: final_df = build_excel(monthly_df, pred_df, EXCEL_OUT)")
else:
    print("✓ All checks passed! Excel file should exist.")
# Out:
# [DIAG] Checking pipeline status...
#
# 1. LightGBM Model:
#    Status: ❌ FAILED or None
#    ✗ train_model() returned None — CHECK TRAINING OUTPUT ABOVE
#
# 2. Engineered Features DataFrame:
#    ✗ eng_df is empty or None
#
# 3. Monthly Prices:
#    ✗ monthly_df is empty/None — RE-RUN: monthly_df = build_monthly_prices(eng_df, TEMPLATE_MONTHS)
#
# 4. Predictions:
#    ✗ pred_df is empty/None — RE-RUN: pred_df = generate_all_predictions(lgbm_model, meta_model, eng_df, QUERY_DATE)
#
# 5. Excel Output:
#    ✗ File NOT CREATED: vehicle_price_forecast_2_0.xlsx
#
# ======================================================================
# WHAT TO DO NEXT:
# ======================================================================
# → train_model() returned None. Check training output for [ERROR] messages.

# %%
# Save model artifacts
joblib.dump(lgbm_model, MODEL_OUT)
eng_df.to_parquet('eng_df_v2.parquet', index=False)
print(f"[SAVE] LightGBM → {MODEL_OUT}")
print(f"[SAVE] Feature DataFrame → eng_df_v2.parquet")

# Quick verification: re-open Excel and print first 3 rows
from openpyxl import load_workbook as _lw
wb_check = _lw(EXCEL_OUT, data_only=True)
ws_check = wb_check.active

print(f"\n[VERIFY] Excel file: {EXCEL_OUT}")
print(f" Rows: {ws_check.max_row-3:,} data rows (excl. title+spacer+header)")
print(f" Cols: {ws_check.max_column}")
print()
print("Headers:")
print("  " + " | ".join(str(ws_check.cell(3, c).value) for c in range(1, 13)))
print()
print("Row 1 sample:")
print("  " + " | ".join(str(ws_check.cell(4, c).value) for c in range(1, 13)))
print()
print("Row 2 sample:")
print("  " + " | ".join(str(ws_check.cell(5, c).value) for c in range(1, 13)))
# Out:
# [SAVE] LightGBM → lgbm_vehicle_price_model_v3_2_0.pkl
# [SAVE] Feature DataFrame → eng_df_v2.parquet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[284], line 9
#       7 # Quick verification: re-open Excel and print first 3 rows
#       8 from openpyxl import load_workbook as _lw
# ----> 9 wb_check = _lw(EXCEL_OUT, data_only=True)
#      10 ws_check = wb_check.active
#      12 print(f"\n[VERIFY] Excel file: {EXCEL_OUT}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\reader\excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     317                   data_only=False, keep_links=True, rich_text=False):
#     318     """Open the given filename and return the workbook
#     319
#     320     :param filename: the path to open or a file-like object
#    (...)    344
#     345     """
# --> 346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
#     348     reader.read()
#     349     return reader.wb
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\reader\excel.py:123, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121 def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122              data_only=False, keep_links=True, rich_text=False):
# --> 123     self.archive = _validate_archive(fn)
#     124     self.valid_files = self.archive.namelist()
#     125     self.read_only = read_only
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openpyxl\reader\excel.py:95, in _validate_archive(filename)
#      88             msg = ('openpyxl does not support %s file format, '
#      89                    'please check you can open '
#      90                    'it with Excel first. '
#      91                    'Supported formats are: %s') % (file_format,
#      92                                                    ','.join(SUPPORTED_FORMATS))
#      93         raise InvalidFileException(msg)
# ---> 95 archive = ZipFile(filename, 'r')
#      96 return archive
#
# File c:\Program Files\Python312\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'vehicle_price_forecast_2_0.xlsx'

# %%
# =============================================================================
#  FULL PIPELINE — Run this cell to do everything at once
# =============================================================================

print("=" * 70)
print("  AUTOINSIGHT — VEHICLE PRICE PREDICTION → EXCEL OUTPUT")
print("=" * 70)

# Clear old data if exists
for var in ['raw_df', 'eng_df', 'lgbm_model', 'meta_model', 'monthly_df', 'pred_df']:
    if var in dir():
        del vars()[var]

print("\n[1/7] Loading & cleaning data…")
raw_df = load_and_clean(CSV_PATH)

if len(raw_df) == 0:
    print("[ERROR] Failed to load data! Check CSV file.")
    raise ValueError("raw_df is empty")

print("\n[2/7] Deriving vehicle condition…")
raw_df = derive_condition(raw_df)

print("\n[3/7] Engineering features…")
eng_df = engineer_features(raw_df)

# ─── CRITICAL CHECK ───────────────────────────────────────────────────────
print("\n[CHECK] Data integrity before training…")
print(f"  eng_df shape: {eng_df.shape}")
nat_count = eng_df['published date'].isna().sum()
valid_count = eng_df['published date'].notna().sum()
print(f"  Valid dates: {valid_count:,}")
print(f"  NaT dates: {nat_count:,}")

if valid_count < 100:
    print(f"\n[ERROR] ⚠️ Only {valid_count} valid dates! Need at least 100.")
    print("  Issue: Date parsing failed. Check CSV file and date formats.")
    raise ValueError("Not enough valid dates for training")

print("\n[4/7] Training model…")
lgbm_model, meta_model, eng_df = train_model(eng_df)

if lgbm_model is None:
    print("[ERROR] Training failed! Model is None.")
    raise ValueError("train_model() returned None")

print("\n[5/7] Computing historical monthly prices…")
monthly_df = build_monthly_prices(eng_df, TEMPLATE_MONTHS)

if monthly_df is None or len(monthly_df) == 0:
    print("[ERROR] Monthly prices failed!")
    raise ValueError("monthly_df is empty")

print(f"\n[MONTHLY] {len(monthly_df):,} vehicle groups × {len(TEMPLATE_MONTHS)} months")

print("\n[6/7] Generating ML predictions for all vehicles…")
pred_df = generate_all_predictions(lgbm_model, meta_model, eng_df, QUERY_DATE)

if pred_df is None or len(pred_df) == 0:
    print("[ERROR] Predictions failed!")
    raise ValueError("pred_df is empty")

print(f"\n[PREDICT] Generated {len(pred_df):,} predictions")
print(f"Sample predictions:\n")
print(pred_df.head(5).to_string(index=False))

print("\n[7/7] Building Excel output…")
final_df = build_excel(monthly_df, pred_df, EXCEL_OUT)

if final_df is None or len(final_df) == 0:
    print("[ERROR] Excel export failed!")
    raise ValueError("Excel export produced no output")

print("\n[SAVE] Saving model artifacts…")
joblib.dump(lgbm_model, MODEL_OUT)
eng_df.to_parquet('eng_df_v2.parquet', index=False)
print(f"  LightGBM model → {MODEL_OUT}")
print(f"  Feature data → eng_df_v2.parquet")

# ─── FINAL VERIFICATION ───────────────────────────────────────────────────
print("\n[VERIFY] Verifying Excel output…")
from openpyxl import load_workbook as _lw
try:
    wb_check = _lw(EXCEL_OUT, data_only=True)
    ws_check = wb_check.active
    data_rows = ws_check.max_row - 3  # Exclude title, spacer, header
    
    print(f"  Data rows: {data_rows:,}")
    print(f"  Columns: {ws_check.max_column}")
    print(f"  Headers: {[ws_check.cell(3, c).value for c in range(1, 13)]}")
    print(f"\n  Sample row 1: {[ws_check.cell(4, c).value for c in range(1, 13)]}")
except Exception as e:
    print(f"  [WARN] Could not verify Excel: {str(e)}")

# ─── SUCCESS ───────────────────────────────────────────────────────────────
print("\n" + "=" * 70)
print("  ✓ PIPELINE COMPLETE!")
print("=" * 70)
print(f"\nOutputs:")
print(f"  Excel file      : {EXCEL_OUT}")
print(f"  Model PKL       : {MODEL_OUT}")
print(f"  Features parquet: eng_df_v2.parquet")
print(f"\nSummary:")
print(f"  Vehicles        : {len(eng_df):,} total rows")
print(f"  Groups          : {len(pred_df):,} (Make/Model/Year combinations)")
print(f"  Predictions     : {len(final_df):,} rows in Excel")
print(f"  Model type      : LightGBM + optional stacking")
print(f"  Generated       : {QUERY_DATE}")
print("=" * 70)
# Out:
# ======================================================================
#   AUTOINSIGHT — VEHICLE PRICE PREDICTION → EXCEL OUTPUT
# ======================================================================
#
# [1/7] Loading & cleaning data…
# [LOAD] CSV loaded: (13353, 9)
# [LOAD] Columns: ['Vehicle Type', 'Make', 'Model', 'Year', 'Price', 'Milleage', 'District', 'published date', 'Vehicle URL']
#
# [DATE] Parsing dates...
# [DATE] Parsed: 13,353 | Failed: 0
# [DATE] Date range: 2025-12-21 → 2026-03-22
#
# [PRICE] Parsing price format...
# [PRICE] Valid prices: 10,349
# [CLEAN] After dropna: (11732, 9)
# [CLEAN] After outlier removal: (8928, 9)
# [DEDUP] Removed 0 duplicate listings
#
# [DATA] 8,928 rows | 62 makes | 2107 models | 1948.0–2026.0
#
#
# [2/7] Deriving vehicle condition…
# [CONDITION] {'Used': 8190, 'Recondition': 404, 'Brand New': 334}
#
# [3/7] Engineering features…
# [FEATURES] 34 columns | 8,928 rows
#
# [CHECK] Data integrity before training…
#   eng_df shape: (8928, 34)
#   Valid dates: 8,928
#   NaT dates: 0
#
# [4/7] Training model…
#
# [SPLIT] Date range: 2025-12-21 to 2026-03-22 (91 days)
# [SPLIT] Valid rows with dates: 8,928 / 8,928
# [SPLIT] TEST_SPLIT_DAYS auto-adjusted: 90 → 27 days
# [SPLIT] Temporal: Train: 2,009  |  Test: 6,919
# [DEBUG] X_train: (2009, 24), X_test: (6919, 24)
# [DEBUG] NaN in X_train: 0, NaN in X_test: 0
# [DEBUG] HPO split: X_tr: (1908, 24), X_va: (101, 24)
# [HPO] Running 5 Optuna trials…
# Best trial: 3. Best value: 0.0836601: 100%|██████████| 5/5 [00:01<00:00,  2.74it/s]
# [HPO] Best MAPE: 8.37%
#
# [TRAIN] Training LightGBM…
# [500]	valid_0's l2: 0.015963
# [TRAIN] LightGBM done. Best iteration: 662
# [STACK] Training XGBoost…
# [STACK]   XGBoost training failed: XGBModel.fit() got an unexpected keyword argument 'early_stopping_rounds'
# [STACK] Training CatBoost…
# [STACK] ✓ CatBoost done
# [STACK] Fitting Ridge meta-learner…
# [STACK] ✓ Meta-learner done
#
# =========================================================
#   MODEL PERFORMANCE (TEST SET — 6,919 samples)
# =========================================================
#   R²       : 0.9622    Excellent
#   Accuracy : 90.73%  (100 - MAPE)
#   MAE      : LKR      522,029
#   RMSE     : LKR    1,066,008
#   MAPE     : 9.27%   ⚠️  check
#   RMSLE    : 0.1675   ⚠️  check
#   MASE     : 0.1337   ✓ ok
# =========================================================
#   Within ±5%  : 53.1%  of predictions
#   Within ±10% : 79.2%  of predictions
#   Within ±15% : 89.3%  of predictions
#
#
# [5/7] Computing historical monthly prices…
#
# [MONTHLY] 8,491,210 vehicle groups × 6 months
#
# [6/7] Generating ML predictions for all vehicles…
# [PREDICT] Generating predictions for 8,491,210 vehicle groups…
# [WARN] Row 1 prediction error: cannot convert float NaN to integer
# [WARN] Row 2 prediction error: cannot convert float NaN to integer
# [WARN] Row 3 prediction error: cannot convert float NaN to integer
# [WARN] Row 4 prediction error: cannot convert float NaN to integer
# [WARN] Row 5 prediction error: cannot convert float NaN to integer
# [WARN] Row 6 prediction error: cannot convert float NaN to integer
# [WARN] Row 7 prediction error: cannot convert float NaN to integer
# [WARN] Row 8 prediction error: cannot convert float NaN to integer
# [WARN] Row 9 prediction error: cannot convert float NaN to integer
# [WARN] Row 10 prediction error: cannot convert float NaN to integer
# [WARN] Row 11 prediction error: cannot convert float NaN to integer
# [WARN] Row 12 prediction error: cannot convert float NaN to integer
# [WARN] Row 13 prediction error: cannot convert float NaN to integer
# [WARN] Row 14 prediction error: cannot convert float NaN to integer
# [WARN] Row 15 prediction error: cannot convert float NaN to integer
# [WARN] Row 16 prediction error: cannot convert float NaN to integer
# [WARN] Row 17 prediction error: cannot convert float NaN to integer
# [WARN] Row 18 prediction error: cannot convert float NaN to integer
# [WARN] Row 19 prediction error: cannot convert float NaN to integer
# [WARN] Row 20 prediction error: cannot convert float NaN to integer
# [WARN] Row 21 prediction error: cannot convert float NaN to integer
# [WARN] Row 22 prediction error: cannot convert float NaN to integer
# [WARN] Row 23 prediction error: cannot convert float NaN to integer
# [WARN] Row 24 prediction error: cannot convert float NaN to integer
# [WARN] Row 25 prediction error: cannot convert float NaN to integer
# [WARN] Row 26 prediction error: cannot convert float NaN to integer
# [WARN] Row 27 prediction error: cannot convert float NaN to integer
# [WARN] Row 28 prediction error: cannot convert float NaN to integer
# [WARN] Row 29 prediction error: cannot convert float NaN to integer
# [WARN] Row 30 prediction error: cannot convert float NaN to integer
# [WARN] Row 31 prediction error: cannot convert float NaN to integer
# [WARN] Row 32 prediction error: cannot convert float NaN to integer
# [WARN] Row 33 prediction error: cannot convert float NaN to integer
# [WARN] Row 34 prediction error: cannot convert float NaN to integer
# [WARN] Row 35 prediction error: cannot convert float NaN to integer
# [WARN] Row 36 prediction error: cannot convert float NaN to integer
# [WARN] Row 37 prediction error: cannot convert float NaN to integer
# [WARN] Row 38 prediction error: cannot convert float NaN to integer
# [WARN] Row 39 prediction error: cannot convert float NaN to integer
# [WARN] Row 40 prediction error: cannot convert float NaN to integer
# [WARN] Row 41 prediction error: cannot convert float NaN to integer
# [WARN] Row 42 prediction error: cannot convert float NaN to integer
# [WARN] Row 43 prediction error: cannot convert float NaN to integer
# [WARN] Row 44 prediction error: cannot convert float NaN to integer
# [WARN] Row 45 prediction error: cannot convert float NaN to integer
# [WARN] Row 46 prediction error: cannot convert float NaN to integer
# [WARN] Row 47 prediction error: cannot convert float NaN to integer
# [WARN] Row 48 prediction error: cannot convert float NaN to integer
# [WARN] Row 49 prediction error: cannot convert float NaN to integer
# [WARN] Row 50 prediction error: cannot convert float NaN to integer
# [WARN] Row 51 prediction error: cannot convert float NaN to integer
# [WARN] Row 52 prediction error: cannot convert float NaN to integer
# [WARN] Row 53 prediction error: cannot convert float NaN to integer
# [WARN] Row 54 prediction error: cannot convert float NaN to integer
# [WARN] Row 55 prediction error: cannot convert float NaN to integer
# [WARN] Row 56 prediction error: cannot convert float NaN to integer
# [WARN] Row 57 prediction error: cannot convert float NaN to integer
# [WARN] Row 58 prediction error: cannot convert float NaN to integer
# [WARN] Row 59 prediction error: cannot convert float NaN to integer
# [WARN] Row 60 prediction error: cannot convert float NaN to integer
# [WARN] Row 61 prediction error: cannot convert float NaN to integer
# [WARN] Row 62 prediction error: cannot convert float NaN to integer
# [WARN] Row 63 prediction error: cannot convert float NaN to integer
# [WARN] Row 64 prediction error: cannot convert float NaN to integer
# [WARN] Row 65 prediction error: cannot convert float NaN to integer
# [WARN] Row 66 prediction error: cannot convert float NaN to integer
# [WARN] Row 67 prediction error: cannot convert float NaN to integer
# [WARN] Row 68 prediction error: cannot convert float NaN to integer
# [WARN] Row 69 prediction error: cannot convert float NaN to integer
# [WARN] Row 70 prediction error: cannot convert float NaN to integer
# [WARN] Row 71 prediction error: cannot convert float NaN to integer
# [WARN] Row 72 prediction error: cannot convert float NaN to integer
# [WARN] Row 73 prediction error: cannot convert float NaN to integer
# [WARN] Row 74 prediction error: cannot convert float NaN to integer
# [WARN] Row 75 prediction error: cannot convert float NaN to integer
# [WARN] Row 76 prediction error: cannot convert float NaN to integer
# [WARN] Row 77 prediction error: cannot convert float NaN to integer
# [WARN] Row 78 prediction error: cannot convert float NaN to integer
# [WARN] Row 79 prediction error: cannot convert float NaN to integer
# [WARN] Row 80 prediction error: cannot convert float NaN to integer
# [WARN] Row 81 prediction error: cannot convert float NaN to integer
# [WARN] Row 82 prediction error: cannot convert float NaN to integer
# [WARN] Row 83 prediction error: cannot convert float NaN to integer
# [WARN] Row 84 prediction error: cannot convert float NaN to integer
# [WARN] Row 85 prediction error: cannot convert float NaN to integer
# [WARN] Row 86 prediction error: cannot convert float NaN to integer
# [WARN] Row 87 prediction error: cannot convert float NaN to integer
# [WARN] Row 88 prediction error: cannot convert float NaN to integer
# [WARN] Row 89 prediction error: cannot convert float NaN to integer
# [WARN] Row 90 prediction error: cannot convert float NaN to integer
# [WARN] Row 91 prediction error: cannot convert float NaN to integer
# [WARN] Row 92 prediction error: cannot convert float NaN to integer
# [WARN] Row 93 prediction error: cannot convert float NaN to integer
# [WARN] Row 94 prediction error: cannot convert float NaN to integer
# [WARN] Row 95 prediction error: cannot convert float NaN to integer
# [WARN] Row 96 prediction error: cannot convert float NaN to integer
# [WARN] Row 97 prediction error: cannot convert float NaN to integer
# [WARN] Row 98 prediction error: cannot convert float NaN to integer
# [WARN] Row 99 prediction error: cannot convert float NaN to integer
# [WARN] Row 100 prediction error: cannot convert float NaN to integer
# [WARN] Row 101 prediction error: cannot convert float NaN to integer
# [WARN] Row 102 prediction error: cannot convert float NaN to integer
# [WARN] Row 103 prediction error: cannot convert float NaN to integer
# [WARN] Row 104 prediction error: cannot convert float NaN to integer
# [WARN] Row 105 prediction error: cannot convert float NaN to integer
# [WARN] Row 106 prediction error: cannot convert float NaN to integer
# [WARN] Row 107 prediction error: cannot convert float NaN to integer
# [WARN] Row 108 prediction error: cannot convert float NaN to integer
# [WARN] Row 109 prediction error: cannot convert float NaN to integer
# [WARN] Row 110 prediction error: cannot convert float NaN to integer
# [WARN] Row 111 prediction error: cannot convert float NaN to integer
# [WARN] Row 112 prediction error: cannot convert float NaN to integer
# [WARN] Row 113 prediction error: cannot convert float NaN to integer
# [WARN] Row 114 prediction error: cannot convert float NaN to integer
# [WARN] Row 115 prediction error: cannot convert float NaN to integer
# [WARN] Row 116 prediction error: cannot convert float NaN to integer
# [WARN] Row 117 prediction error: cannot convert float NaN to integer
# [WARN] Row 118 prediction error: cannot convert float NaN to integer
# [WARN] Row 119 prediction error: cannot convert float NaN to integer
# [WARN] Row 120 prediction error: cannot convert float NaN to integer
# [WARN] Row 121 prediction error: cannot convert float NaN to integer
# [WARN] Row 122 prediction error: cannot convert float NaN to integer
# [WARN] Row 123 prediction error: cannot convert float NaN to integer
# [WARN] Row 124 prediction error: cannot convert float NaN to integer
# [WARN] Row 125 prediction error: cannot convert float NaN to integer
# [WARN] Row 126 prediction error: cannot convert float NaN to integer
# [WARN] Row 127 prediction error: cannot convert float NaN to integer
# [WARN] Row 128 prediction error: cannot convert float NaN to integer
# [WARN] Row 129 prediction error: cannot convert float NaN to integer
# [WARN] Row 130 prediction error: cannot convert float NaN to integer
# [WARN] Row 131 prediction error: cannot convert float NaN to integer
# [WARN] Row 132 prediction error: cannot convert float NaN to integer
# [WARN] Row 133 prediction error: cannot convert float NaN to integer
# [WARN] Row 134 prediction error: cannot convert float NaN to integer
# [WARN] Row 135 prediction error: cannot convert float NaN to integer
# [WARN] Row 136 prediction error: cannot convert float NaN to integer
# [WARN] Row 137 prediction error: cannot convert float NaN to integer
# [WARN] Row 138 prediction error: cannot convert float NaN to integer
# [WARN] Row 139 prediction error: cannot convert float NaN to integer
# [WARN] Row 140 prediction error: cannot convert float NaN to integer
# [WARN] Row 141 prediction error: cannot convert float NaN to integer
# [WARN] Row 142 prediction error: cannot convert float NaN to integer
# [WARN] Row 143 prediction error: cannot convert float NaN to integer
# [WARN] Row 144 prediction error: cannot convert float NaN to integer
# [WARN] Row 145 prediction error: cannot convert float NaN to integer
# [WARN] Row 146 prediction error: cannot convert float NaN to integer
# [WARN] Row 147 prediction error: cannot convert float NaN to integer
# [WARN] Row 148 prediction error: cannot convert float NaN to integer
# [WARN] Row 149 prediction error: cannot convert float NaN to integer
# [WARN] Row 150 prediction error: cannot convert float NaN to integer
# [WARN] Row 151 prediction error: cannot convert float NaN to integer
# [WARN] Row 152 prediction error: cannot convert float NaN to integer
# [WARN] Row 153 prediction error: cannot convert float NaN to integer
# [WARN] Row 154 prediction error: cannot convert float NaN to integer
# [WARN] Row 155 prediction error: cannot convert float NaN to integer
# [WARN] Row 156 prediction error: cannot convert float NaN to integer
# [WARN] Row 157 prediction error: cannot convert float NaN to integer
# [WARN] Row 158 prediction error: cannot convert float NaN to integer
# [WARN] Row 159 prediction error: cannot convert float NaN to integer
# [WARN] Row 160 prediction error: cannot convert float NaN to integer
# [WARN] Row 161 prediction error: cannot convert float NaN to integer
# [WARN] Row 162 prediction error: cannot convert float NaN to integer
# [WARN] Row 163 prediction error: cannot convert float NaN to integer
# [WARN] Row 164 prediction error: cannot convert float NaN to integer
# [WARN] Row 165 prediction error: cannot convert float NaN to integer
# [WARN] Row 166 prediction error: cannot convert float NaN to integer
# [WARN] Row 167 prediction error: cannot convert float NaN to integer
# [WARN] Row 168 prediction error: cannot convert float NaN to integer
# [WARN] Row 169 prediction error: cannot convert float NaN to integer
# [WARN] Row 170 prediction error: cannot convert float NaN to integer
# [WARN] Row 171 prediction error: cannot convert float NaN to integer
# [WARN] Row 172 prediction error: cannot convert float NaN to integer
# [WARN] Row 173 prediction error: cannot convert float NaN to integer
# [WARN] Row 174 prediction error: cannot convert float NaN to integer
# [WARN] Row 175 prediction error: cannot convert float NaN to integer
# [WARN] Row 176 prediction error: cannot convert float NaN to integer
# [WARN] Row 177 prediction error: cannot convert float NaN to integer
# [WARN] Row 178 prediction error: cannot convert float NaN to integer
# [WARN] Row 179 prediction error: cannot convert float NaN to integer
# [WARN] Row 180 prediction error: cannot convert float NaN to integer
# [WARN] Row 181 prediction error: cannot convert float NaN to integer
# [WARN] Row 182 prediction error: cannot convert float NaN to integer
# [WARN] Row 183 prediction error: cannot convert float NaN to integer
# [WARN] Row 184 prediction error: cannot convert float NaN to integer
# [WARN] Row 185 prediction error: cannot convert float NaN to integer
# [WARN] Row 186 prediction error: cannot convert float NaN to integer
# [WARN] Row 187 prediction error: cannot convert float NaN to integer
# [WARN] Row 188 prediction error: cannot convert float NaN to integer
# [WARN] Row 189 prediction error: cannot convert float NaN to integer
# [WARN] Row 190 prediction error: cannot convert float NaN to integer
# [WARN] Row 191 prediction error: cannot convert float NaN to integer
# [WARN] Row 192 prediction error: cannot convert float NaN to integer
# [WARN] Row 193 prediction error: cannot convert float NaN to integer
# [WARN] Row 194 prediction error: cannot convert float NaN to integer
# [WARN] Row 195 prediction error: cannot convert float NaN to integer
# [WARN] Row 196 prediction error: cannot convert float NaN to integer
# [WARN] Row 197 prediction error: cannot convert float NaN to integer
# [WARN] Row 198 prediction error: cannot convert float NaN to integer
# [WARN] Row 199 prediction error: cannot convert float NaN to integer
# [WARN] Row 200 prediction error: cannot convert float NaN to integer
# [WARN] Row 201 prediction error: cannot convert float NaN to integer
# [WARN] Row 202 prediction error: cannot convert float NaN to integer
# [WARN] Row 203 prediction error: cannot convert float NaN to integer
# [WARN] Row 204 prediction error: cannot convert float NaN to integer
# [WARN] Row 205 prediction error: cannot convert float NaN to integer
# [WARN] Row 206 prediction error: cannot convert float NaN to integer
# [WARN] Row 207 prediction error: cannot convert float NaN to integer
# [WARN] Row 208 prediction error: cannot convert float NaN to integer
# [WARN] Row 209 prediction error: cannot convert float NaN to integer
# [WARN] Row 210 prediction error: cannot convert float NaN to integer
# [WARN] Row 211 prediction error: cannot convert float NaN to integer
# [WARN] Row 212 prediction error: cannot convert float NaN to integer
# [WARN] Row 213 prediction error: cannot convert float NaN to integer
# [WARN] Row 214 prediction error: cannot convert float NaN to integer
# [WARN] Row 215 prediction error: cannot convert float NaN to integer
# [WARN] Row 216 prediction error: cannot convert float NaN to integer
# [WARN] Row 217 prediction error: cannot convert float NaN to integer
# [WARN] Row 218 prediction error: cannot convert float NaN to integer
# [WARN] Row 219 prediction error: cannot convert float NaN to integer
# [WARN] Row 220 prediction error: cannot convert float NaN to integer
# [WARN] Row 221 prediction error: cannot convert float NaN to integer
# [WARN] Row 222 prediction error: cannot convert float NaN to integer
# [WARN] Row 223 prediction error: cannot convert float NaN to integer
# [WARN] Row 224 prediction error: cannot convert float NaN to integer
# [WARN] Row 225 prediction error: cannot convert float NaN to integer
# [WARN] Row 226 prediction error: cannot convert float NaN to integer
# [WARN] Row 227 prediction error: cannot convert float NaN to integer
# [WARN] Row 228 prediction error: cannot convert float NaN to integer
# [WARN] Row 229 prediction error: cannot convert float NaN to integer
# [WARN] Row 230 prediction error: cannot convert float NaN to integer
# [WARN] Row 231 prediction error: cannot convert float NaN to integer
# [WARN] Row 232 prediction error: cannot convert float NaN to integer
# [WARN] Row 233 prediction error: cannot convert float NaN to integer
# [WARN] Row 234 prediction error: cannot convert float NaN to integer
# [WARN] Row 235 prediction error: cannot convert float NaN to integer
# [WARN] Row 236 prediction error: cannot convert float NaN to integer
# [WARN] Row 237 prediction error: cannot convert float NaN to integer
# [WARN] Row 238 prediction error: cannot convert float NaN to integer
# [WARN] Row 239 prediction error: cannot convert float NaN to integer
# [WARN] Row 240 prediction error: cannot convert float NaN to integer
# [WARN] Row 241 prediction error: cannot convert float NaN to integer
# [WARN] Row 242 prediction error: cannot convert float NaN to integer
# [WARN] Row 243 prediction error: cannot convert float NaN to integer
# [WARN] Row 244 prediction error: cannot convert float NaN to integer
# [WARN] Row 245 prediction error: cannot convert float NaN to integer
# [WARN] Row 246 prediction error: cannot convert float NaN to integer
# [WARN] Row 247 prediction error: cannot convert float NaN to integer
# [WARN] Row 248 prediction error: cannot convert float NaN to integer
# [WARN] Row 249 prediction error: cannot convert float NaN to integer
# [WARN] Row 250 prediction error: cannot convert float NaN to integer
# [WARN] Row 251 prediction error: cannot convert float NaN to integer
# [WARN] Row 252 prediction error: cannot convert float NaN to integer
# [WARN] Row 253 prediction error: cannot convert float NaN to integer
# [WARN] Row 254 prediction error: cannot convert float NaN to integer
# [WARN] Row 255 prediction error: cannot convert float NaN to integer
# [WARN] Row 256 prediction error: cannot convert float NaN to integer
# [WARN] Row 257 prediction error: cannot convert float NaN to integer
# [WARN] Row 258 prediction error: cannot convert float NaN to integer
# [WARN] Row 259 prediction error: cannot convert float NaN to integer
# [WARN] Row 260 prediction error: cannot convert float NaN to integer
# [WARN] Row 261 prediction error: cannot convert float NaN to integer
# [WARN] Row 262 prediction error: cannot convert float NaN to integer
# [WARN] Row 263 prediction error: cannot convert float NaN to integer
# [WARN] Row 264 prediction error: cannot convert float NaN to integer
# [WARN] Row 265 prediction error: cannot convert float NaN to integer
# [WARN] Row 266 prediction error: cannot convert float NaN to integer
# [WARN] Row 267 prediction error: cannot convert float NaN to integer
# [WARN] Row 268 prediction error: cannot convert float NaN to integer
# [WARN] Row 269 prediction error: cannot convert float NaN to integer
# [WARN] Row 270 prediction error: cannot convert float NaN to integer
# [WARN] Row 271 prediction error: cannot convert float NaN to integer
# [WARN] Row 272 prediction error: cannot convert float NaN to integer
# [WARN] Row 273 prediction error: cannot convert float NaN to integer
# [WARN] Row 274 prediction error: cannot convert float NaN to integer
# [WARN] Row 275 prediction error: cannot convert float NaN to integer
# [WARN] Row 276 prediction error: cannot convert float NaN to integer
# [WARN] Row 277 prediction error: cannot convert float NaN to integer
# [WARN] Row 278 prediction error: cannot convert float NaN to integer
# [WARN] Row 279 prediction error: cannot convert float NaN to integer
# [WARN] Row 280 prediction error: cannot convert float NaN to integer
# [WARN] Row 281 prediction error: cannot convert float NaN to integer
# [WARN] Row 282 prediction error: cannot convert float NaN to integer
# [WARN] Row 283 prediction error: cannot convert float NaN to integer
# [WARN] Row 284 prediction error: cannot convert float NaN to integer
# [WARN] Row 285 prediction error: cannot convert float NaN to integer
# [WARN] Row 286 prediction error: cannot convert float NaN to integer
# [WARN] Row 287 prediction error: cannot convert float NaN to integer
# [WARN] Row 288 prediction error: cannot convert float NaN to integer
# [WARN] Row 289 prediction error: cannot convert float NaN to integer
# [WARN] Row 290 prediction error: cannot convert float NaN to integer
# [WARN] Row 291 prediction error: cannot convert float NaN to integer
# [WARN] Row 292 prediction error: cannot convert float NaN to integer
# [WARN] Row 293 prediction error: cannot convert float NaN to integer
# [WARN] Row 294 prediction error: cannot convert float NaN to integer
# [WARN] Row 295 prediction error: cannot convert float NaN to integer
# [WARN] Row 296 prediction error: cannot convert float NaN to integer
# [WARN] Row 297 prediction error: cannot convert float NaN to integer
# [WARN] Row 298 prediction error: cannot convert float NaN to integer
# [WARN] Row 299 prediction error: cannot convert float NaN to integer
# [WARN] Row 300 prediction error: cannot convert float NaN to integer
# [WARN] Row 301 prediction error: cannot convert float NaN to integer
# [WARN] Row 302 prediction error: cannot convert float NaN to integer
# [WARN] Row 303 prediction error: cannot convert float NaN to integer
# [WARN] Row 304 prediction error: cannot convert float NaN to integer
# [WARN] Row 305 prediction error: cannot convert float NaN to integer
# [WARN] Row 306 prediction error: cannot convert float NaN to integer
# [WARN] Row 307 prediction error: cannot convert float NaN to integer
# [WARN] Row 308 prediction error: cannot convert float NaN to integer
# [WARN] Row 309 prediction error: cannot convert float NaN to integer
# [WARN] Row 310 prediction error: cannot convert float NaN to integer
# [WARN] Row 311 prediction error: cannot convert float NaN to integer
# [WARN] Row 312 prediction error: cannot convert float NaN to integer
# [WARN] Row 313 prediction error: cannot convert float NaN to integer
# [WARN] Row 314 prediction error: cannot convert float NaN to integer
# [WARN] Row 315 prediction error: cannot convert float NaN to integer
# [WARN] Row 316 prediction error: cannot convert float NaN to integer
# [WARN] Row 317 prediction error: cannot convert float NaN to integer
# [WARN] Row 318 prediction error: cannot convert float NaN to integer
# [WARN] Row 319 prediction error: cannot convert float NaN to integer
# [WARN] Row 320 prediction error: cannot convert float NaN to integer
# [WARN] Row 321 prediction error: cannot convert float NaN to integer
# [WARN] Row 322 prediction error: cannot convert float NaN to integer
# [WARN] Row 323 prediction error: cannot convert float NaN to integer
# [WARN] Row 324 prediction error: cannot convert float NaN to integer
# [WARN] Row 325 prediction error: cannot convert float NaN to integer
# [WARN] Row 326 prediction error: cannot convert float NaN to integer
# [WARN] Row 327 prediction error: cannot convert float NaN to integer
# [WARN] Row 328 prediction error: cannot convert float NaN to integer
# [WARN] Row 329 prediction error: cannot convert float NaN to integer
# [WARN] Row 330 prediction error: cannot convert float NaN to integer
# [WARN] Row 331 prediction error: cannot convert float NaN to integer
# [WARN] Row 332 prediction error: cannot convert float NaN to integer
# [WARN] Row 333 prediction error: cannot convert float NaN to integer
# [WARN] Row 334 prediction error: cannot convert float NaN to integer
# [WARN] Row 335 prediction error: cannot convert float NaN to integer
# [WARN] Row 336 prediction error: cannot convert float NaN to integer
# [WARN] Row 337 prediction error: cannot convert float NaN to integer
# [WARN] Row 338 prediction error: cannot convert float NaN to integer
# [WARN] Row 339 prediction error: cannot convert float NaN to integer
# [WARN] Row 340 prediction error: cannot convert float NaN to integer
# [WARN] Row 341 prediction error: cannot convert float NaN to integer
# [WARN] Row 342 prediction error: cannot convert float NaN to integer
# [WARN] Row 343 prediction error: cannot convert float NaN to integer
# [WARN] Row 344 prediction error: cannot convert float NaN to integer
# [WARN] Row 345 prediction error: cannot convert float NaN to integer
# [WARN] Row 346 prediction error: cannot convert float NaN to integer
# [WARN] Row 347 prediction error: cannot convert float NaN to integer
# [WARN] Row 348 prediction error: cannot convert float NaN to integer
# [WARN] Row 349 prediction error: cannot convert float NaN to integer
# [WARN] Row 350 prediction error: cannot convert float NaN to integer
# [WARN] Row 351 prediction error: cannot convert float NaN to integer
# [WARN] Row 352 prediction error: cannot convert float NaN to integer
# [WARN] Row 353 prediction error: cannot convert float NaN to integer
# [WARN] Row 354 prediction error: cannot convert float NaN to integer
# [WARN] Row 355 prediction error: cannot convert float NaN to integer
# [WARN] Row 356 prediction error: cannot convert float NaN to integer
# [WARN] Row 357 prediction error: cannot convert float NaN to integer
# [WARN] Row 358 prediction error: cannot convert float NaN to integer
# [WARN] Row 359 prediction error: cannot convert float NaN to integer
# [WARN] Row 360 prediction error: cannot convert float NaN to integer
# [WARN] Row 361 prediction error: cannot convert float NaN to integer
# [WARN] Row 362 prediction error: cannot convert float NaN to integer
# [WARN] Row 363 prediction error: cannot convert float NaN to integer
# [WARN] Row 364 prediction error: cannot convert float NaN to integer
# [WARN] Row 365 prediction error: cannot convert float NaN to integer
# [WARN] Row 366 prediction error: cannot convert float NaN to integer
# [WARN] Row 367 prediction error: cannot convert float NaN to integer
# [WARN] Row 368 prediction error: cannot convert float NaN to integer
# [WARN] Row 369 prediction error: cannot convert float NaN to integer
# [WARN] Row 370 prediction error: cannot convert float NaN to integer
# [WARN] Row 371 prediction error: cannot convert float NaN to integer
# [WARN] Row 372 prediction error: cannot convert float NaN to integer
# [WARN] Row 373 prediction error: cannot convert float NaN to integer
# [WARN] Row 374 prediction error: cannot convert float NaN to integer
# [WARN] Row 375 prediction error: cannot convert float NaN to integer
# [WARN] Row 376 prediction error: cannot convert float NaN to integer
# [WARN] Row 377 prediction error: cannot convert float NaN to integer
# [WARN] Row 378 prediction error: cannot convert float NaN to integer
# [WARN] Row 379 prediction error: cannot convert float NaN to integer
# [WARN] Row 380 prediction error: cannot convert float NaN to integer
# [WARN] Row 381 prediction error: cannot convert float NaN to integer
# [WARN] Row 382 prediction error: cannot convert float NaN to integer
# [WARN] Row 383 prediction error: cannot convert float NaN to integer
# [WARN] Row 384 prediction error: cannot convert float NaN to integer
# [WARN] Row 385 prediction error: cannot convert float NaN to integer
# [WARN] Row 386 prediction error: cannot convert float NaN to integer
# [WARN] Row 387 prediction error: cannot convert float NaN to integer
# [WARN] Row 388 prediction error: cannot convert float NaN to integer
# [WARN] Row 389 prediction error: cannot convert float NaN to integer
# [WARN] Row 390 prediction error: cannot convert float NaN to integer
# [WARN] Row 391 prediction error: cannot convert float NaN to integer
# [WARN] Row 392 prediction error: cannot convert float NaN to integer
# [WARN] Row 393 prediction error: cannot convert float NaN to integer
# [WARN] Row 394 prediction error: cannot convert float NaN to integer
# [WARN] Row 395 prediction error: cannot convert float NaN to integer
# [WARN] Row 396 prediction error: cannot convert float NaN to integer
# [WARN] Row 397 prediction error: cannot convert float NaN to integer
# [WARN] Row 398 prediction error: cannot convert float NaN to integer
# [WARN] Row 399 prediction error: cannot convert float NaN to integer
# [WARN] Row 400 prediction error: cannot convert float NaN to integer
# [WARN] Row 401 prediction error: cannot convert float NaN to integer
# [WARN] Row 402 prediction error: cannot convert float NaN to integer
# [WARN] Row 403 prediction error: cannot convert float NaN to integer
# [WARN] Row 404 prediction error: cannot convert float NaN to integer
# [WARN] Row 405 prediction error: cannot convert float NaN to integer
# [WARN] Row 406 prediction error: cannot convert float NaN to integer
# [WARN] Row 407 prediction error: cannot convert float NaN to integer
# [WARN] Row 408 prediction error: cannot convert float NaN to integer
# [WARN] Row 409 prediction error: cannot convert float NaN to integer
# [WARN] Row 410 prediction error: cannot convert float NaN to integer
# [WARN] Row 411 prediction error: cannot convert float NaN to integer
# [WARN] Row 412 prediction error: cannot convert float NaN to integer
# [WARN] Row 413 prediction error: cannot convert float NaN to integer
# [WARN] Row 414 prediction error: cannot convert float NaN to integer
# [WARN] Row 415 prediction error: cannot convert float NaN to integer
# [WARN] Row 416 prediction error: cannot convert float NaN to integer
# [WARN] Row 417 prediction error: cannot convert float NaN to integer
# [WARN] Row 418 prediction error: cannot convert float NaN to integer
# [WARN] Row 419 prediction error: cannot convert float NaN to integer
# [WARN] Row 420 prediction error: cannot convert float NaN to integer
# [WARN] Row 421 prediction error: cannot convert float NaN to integer
# [WARN] Row 422 prediction error: cannot convert float NaN to integer
# [WARN] Row 423 prediction error: cannot convert float NaN to integer
# [WARN] Row 424 prediction error: cannot convert float NaN to integer
# [WARN] Row 425 prediction error: cannot convert float NaN to integer
# [WARN] Row 426 prediction error: cannot convert float NaN to integer
# [WARN] Row 427 prediction error: cannot convert float NaN to integer
# [WARN] Row 428 prediction error: cannot convert float NaN to integer
# [WARN] Row 429 prediction error: cannot convert float NaN to integer
# [WARN] Row 430 prediction error: cannot convert float NaN to integer
# [WARN] Row 431 prediction error: cannot convert float NaN to integer
# [WARN] Row 432 prediction error: cannot convert float NaN to integer
# [WARN] Row 433 prediction error: cannot convert float NaN to integer
# [WARN] Row 434 prediction error: cannot convert float NaN to integer
# [WARN] Row 435 prediction error: cannot convert float NaN to integer
# [WARN] Row 436 prediction error: cannot convert float NaN to integer
# [WARN] Row 437 prediction error: cannot convert float NaN to integer
# [WARN] Row 438 prediction error: cannot convert float NaN to integer
# [WARN] Row 439 prediction error: cannot convert float NaN to integer
# [WARN] Row 440 prediction error: cannot convert float NaN to integer
# [WARN] Row 441 prediction error: cannot convert float NaN to integer
# [WARN] Row 442 prediction error: cannot convert float NaN to integer
# [WARN] Row 443 prediction error: cannot convert float NaN to integer
# [WARN] Row 444 prediction error: cannot convert float NaN to integer
# [WARN] Row 445 prediction error: cannot convert float NaN to integer
# [WARN] Row 446 prediction error: cannot convert float NaN to integer
# [WARN] Row 447 prediction error: cannot convert float NaN to integer
# [WARN] Row 448 prediction error: cannot convert float NaN to integer
# [WARN] Row 449 prediction error: cannot convert float NaN to integer
# [WARN] Row 450 prediction error: cannot convert float NaN to integer
# [WARN] Row 451 prediction error: cannot convert float NaN to integer
# [WARN] Row 452 prediction error: cannot convert float NaN to integer
# [WARN] Row 453 prediction error: cannot convert float NaN to integer
# [WARN] Row 454 prediction error: cannot convert float NaN to integer
# [WARN] Row 455 prediction error: cannot convert float NaN to integer
# [WARN] Row 456 prediction error: cannot convert float NaN to integer
# [WARN] Row 457 prediction error: cannot convert float NaN to integer
# [WARN] Row 458 prediction error: cannot convert float NaN to integer
# [WARN] Row 459 prediction error: cannot convert float NaN to integer
# [WARN] Row 460 prediction error: cannot convert float NaN to integer
# [WARN] Row 461 prediction error: cannot convert float NaN to integer
# [WARN] Row 462 prediction error: cannot convert float NaN to integer
# [WARN] Row 463 prediction error: cannot convert float NaN to integer
# [WARN] Row 464 prediction error: cannot convert float NaN to integer
# [WARN] Row 465 prediction error: cannot convert float NaN to integer
# [WARN] Row 466 prediction error: cannot convert float NaN to integer
# [WARN] Row 467 prediction error: cannot convert float NaN to integer
# [WARN] Row 468 prediction error: cannot convert float NaN to integer
# [WARN] Row 469 prediction error: cannot convert float NaN to integer
# [WARN] Row 470 prediction error: cannot convert float NaN to integer
# [WARN] Row 471 prediction error: cannot convert float NaN to integer
# [WARN] Row 472 prediction error: cannot convert float NaN to integer
# [WARN] Row 473 prediction error: cannot convert float NaN to integer
# [WARN] Row 474 prediction error: cannot convert float NaN to integer
# [WARN] Row 475 prediction error: cannot convert float NaN to integer
# [WARN] Row 476 prediction error: cannot convert float NaN to integer
# [WARN] Row 477 prediction error: cannot convert float NaN to integer
# [WARN] Row 478 prediction error: cannot convert float NaN to integer
# [WARN] Row 479 prediction error: cannot convert float NaN to integer
# [WARN] Row 480 prediction error: cannot convert float NaN to integer
# [WARN] Row 481 prediction error: cannot convert float NaN to integer
# [WARN] Row 482 prediction error: cannot convert float NaN to integer
# [WARN] Row 483 prediction error: cannot convert float NaN to integer
# [WARN] Row 484 prediction error: cannot convert float NaN to integer
# [WARN] Row 485 prediction error: cannot convert float NaN to integer
# [WARN] Row 486 prediction error: cannot convert float NaN to integer
# [WARN] Row 487 prediction error: cannot convert float NaN to integer
# [WARN] Row 488 prediction error: cannot convert float NaN to integer
# [WARN] Row 489 prediction error: cannot convert float NaN to integer
# [WARN] Row 490 prediction error: cannot convert float NaN to integer
# [WARN] Row 491 prediction error: cannot convert float NaN to integer
# [WARN] Row 492 prediction error: cannot convert float NaN to integer
# [WARN] Row 493 prediction error: cannot convert float NaN to integer
# [WARN] Row 494 prediction error: cannot convert float NaN to integer
# [WARN] Row 495 prediction error: cannot convert float NaN to integer
# [WARN] Row 496 prediction error: cannot convert float NaN to integer
# [WARN] Row 497 prediction error: cannot convert float NaN to integer
# [WARN] Row 498 prediction error: cannot convert float NaN to integer
# [WARN] Row 499 prediction error: cannot convert float NaN to integer
# [WARN] Row 500 prediction error: cannot convert float NaN to integer
# [WARN] Row 501 prediction error: cannot convert float NaN to integer
# [WARN] Row 502 prediction error: cannot convert float NaN to integer
# [WARN] Row 503 prediction error: cannot convert float NaN to integer
# [WARN] Row 504 prediction error: cannot convert float NaN to integer
# [WARN] Row 505 prediction error: cannot convert float NaN to integer
# [WARN] Row 506 prediction error: cannot convert float NaN to integer
# [WARN] Row 507 prediction error: cannot convert float NaN to integer
# [WARN] Row 508 prediction error: cannot convert float NaN to integer
# [WARN] Row 509 prediction error: cannot convert float NaN to integer
# [WARN] Row 510 prediction error: cannot convert float NaN to integer
# [WARN] Row 511 prediction error: cannot convert float NaN to integer
# [WARN] Row 512 prediction error: cannot convert float NaN to integer
# [WARN] Row 513 prediction error: cannot convert float NaN to integer
# [WARN] Row 514 prediction error: cannot convert float NaN to integer
# [WARN] Row 515 prediction error: cannot convert float NaN to integer
# [WARN] Row 516 prediction error: cannot convert float NaN to integer
# [WARN] Row 517 prediction error: cannot convert float NaN to integer
# [WARN] Row 518 prediction error: cannot convert float NaN to integer
# [WARN] Row 519 prediction error: cannot convert float NaN to integer
# [WARN] Row 520 prediction error: cannot convert float NaN to integer
# [WARN] Row 521 prediction error: cannot convert float NaN to integer
# [WARN] Row 522 prediction error: cannot convert float NaN to integer
# [WARN] Row 523 prediction error: cannot convert float NaN to integer
# [WARN] Row 524 prediction error: cannot convert float NaN to integer
# [WARN] Row 525 prediction error: cannot convert float NaN to integer
# [WARN] Row 526 prediction error: cannot convert float NaN to integer
# [WARN] Row 527 prediction error: cannot convert float NaN to integer
# [WARN] Row 528 prediction error: cannot convert float NaN to integer
# [WARN] Row 529 prediction error: cannot convert float NaN to integer
# [WARN] Row 530 prediction error: cannot convert float NaN to integer
# [WARN] Row 531 prediction error: cannot convert float NaN to integer
# [WARN] Row 532 prediction error: cannot convert float NaN to integer
# [WARN] Row 533 prediction error: cannot convert float NaN to integer
# [WARN] Row 534 prediction error: cannot convert float NaN to integer
# [WARN] Row 535 prediction error: cannot convert float NaN to integer
# [WARN] Row 536 prediction error: cannot convert float NaN to integer
# [WARN] Row 537 prediction error: cannot convert float NaN to integer
# [WARN] Row 538 prediction error: cannot convert float NaN to integer
# [WARN] Row 539 prediction error: cannot convert float NaN to integer
# [WARN] Row 540 prediction error: cannot convert float NaN to integer
# [WARN] Row 541 prediction error: cannot convert float NaN to integer
# [WARN] Row 542 prediction error: cannot convert float NaN to integer
# [WARN] Row 543 prediction error: cannot convert float NaN to integer
# [WARN] Row 544 prediction error: cannot convert float NaN to integer
# [WARN] Row 545 prediction error: cannot convert float NaN to integer
# [WARN] Row 546 prediction error: cannot convert float NaN to integer
# [WARN] Row 547 prediction error: cannot convert float NaN to integer
# [WARN] Row 548 prediction error: cannot convert float NaN to integer
# [WARN] Row 549 prediction error: cannot convert float NaN to integer
# [WARN] Row 550 prediction error: cannot convert float NaN to integer
# [WARN] Row 551 prediction error: cannot convert float NaN to integer
# [WARN] Row 552 prediction error: cannot convert float NaN to integer
# [WARN] Row 553 prediction error: cannot convert float NaN to integer
# [WARN] Row 554 prediction error: cannot convert float NaN to integer
# [WARN] Row 555 prediction error: cannot convert float NaN to integer
# [WARN] Row 556 prediction error: cannot convert float NaN to integer
# [WARN] Row 557 prediction error: cannot convert float NaN to integer
# [WARN] Row 558 prediction error: cannot convert float NaN to integer
# [WARN] Row 559 prediction error: cannot convert float NaN to integer
# [WARN] Row 560 prediction error: cannot convert float NaN to integer
# [WARN] Row 561 prediction error: cannot convert float NaN to integer
# [WARN] Row 562 prediction error: cannot convert float NaN to integer
# [WARN] Row 563 prediction error: cannot convert float NaN to integer
# [WARN] Row 564 prediction error: cannot convert float NaN to integer
# [WARN] Row 565 prediction error: cannot convert float NaN to integer
# [WARN] Row 566 prediction error: cannot convert float NaN to integer
# [WARN] Row 567 prediction error: cannot convert float NaN to integer
# [WARN] Row 568 prediction error: cannot convert float NaN to integer
# [WARN] Row 569 prediction error: cannot convert float NaN to integer
# [WARN] Row 570 prediction error: cannot convert float NaN to integer
# [WARN] Row 571 prediction error: cannot convert float NaN to integer
# [WARN] Row 572 prediction error: cannot convert float NaN to integer
# [WARN] Row 573 prediction error: cannot convert float NaN to integer
# [WARN] Row 574 prediction error: cannot convert float NaN to integer
# [WARN] Row 575 prediction error: cannot convert float NaN to integer
# [WARN] Row 576 prediction error: cannot convert float NaN to integer
# [WARN] Row 577 prediction error: cannot convert float NaN to integer
# [WARN] Row 578 prediction error: cannot convert float NaN to integer
# [WARN] Row 579 prediction error: cannot convert float NaN to integer
# [WARN] Row 580 prediction error: cannot convert float NaN to integer
# [WARN] Row 581 prediction error: cannot convert float NaN to integer
# [WARN] Row 582 prediction error: cannot convert float NaN to integer
# [WARN] Row 583 prediction error: cannot convert float NaN to integer
# [WARN] Row 584 prediction error: cannot convert float NaN to integer
# [WARN] Row 585 prediction error: cannot convert float NaN to integer
# [WARN] Row 586 prediction error: cannot convert float NaN to integer
# [WARN] Row 587 prediction error: cannot convert float NaN to integer
# [WARN] Row 588 prediction error: cannot convert float NaN to integer
# [WARN] Row 589 prediction error: cannot convert float NaN to integer
# [WARN] Row 590 prediction error: cannot convert float NaN to integer
# [WARN] Row 591 prediction error: cannot convert float NaN to integer
# [WARN] Row 592 prediction error: cannot convert float NaN to integer
# [WARN] Row 593 prediction error: cannot convert float NaN to integer
# [WARN] Row 594 prediction error: cannot convert float NaN to integer
# [WARN] Row 595 prediction error: cannot convert float NaN to integer
# [WARN] Row 596 prediction error: cannot convert float NaN to integer
# [WARN] Row 597 prediction error: cannot convert float NaN to integer
# [WARN] Row 598 prediction error: cannot convert float NaN to integer
# [WARN] Row 599 prediction error: cannot convert float NaN to integer
# [WARN] Row 600 prediction error: cannot convert float NaN to integer
# [WARN] Row 601 prediction error: cannot convert float NaN to integer
# [WARN] Row 602 prediction error: cannot convert float NaN to integer
# [WARN] Row 603 prediction error: cannot convert float NaN to integer
# [WARN] Row 604 prediction error: cannot convert float NaN to integer
# [WARN] Row 605 prediction error: cannot convert float NaN to integer
# [WARN] Row 606 prediction error: cannot convert float NaN to integer
# [WARN] Row 607 prediction error: cannot convert float NaN to integer
# [WARN] Row 608 prediction error: cannot convert float NaN to integer
# [WARN] Row 609 prediction error: cannot convert float NaN to integer
# [WARN] Row 610 prediction error: cannot convert float NaN to integer
# [WARN] Row 611 prediction error: cannot convert float NaN to integer
# [WARN] Row 612 prediction error: cannot convert float NaN to integer
# [WARN] Row 613 prediction error: cannot convert float NaN to integer
# [WARN] Row 614 prediction error: cannot convert float NaN to integer
# [WARN] Row 615 prediction error: cannot convert float NaN to integer
# [WARN] Row 616 prediction error: cannot convert float NaN to integer
# [WARN] Row 617 prediction error: cannot convert float NaN to integer
# [WARN] Row 618 prediction error: cannot convert float NaN to integer
# [WARN] Row 619 prediction error: cannot convert float NaN to integer
# [WARN] Row 620 prediction error: cannot convert float NaN to integer
# [WARN] Row 621 prediction error: cannot convert float NaN to integer
# [WARN] Row 622 prediction error: cannot convert float NaN to integer
# [WARN] Row 623 prediction error: cannot convert float NaN to integer
# [WARN] Row 624 prediction error: cannot convert float NaN to integer
# [WARN] Row 625 prediction error: cannot convert float NaN to integer
# [WARN] Row 626 prediction error: cannot convert float NaN to integer
# [WARN] Row 627 prediction error: cannot convert float NaN to integer
# [WARN] Row 628 prediction error: cannot convert float NaN to integer
# [WARN] Row 629 prediction error: cannot convert float NaN to integer
# [WARN] Row 630 prediction error: cannot convert float NaN to integer
# [WARN] Row 631 prediction error: cannot convert float NaN to integer
# [WARN] Row 632 prediction error: cannot convert float NaN to integer
# [WARN] Row 633 prediction error: cannot convert float NaN to integer
# [WARN] Row 634 prediction error: cannot convert float NaN to integer
# [WARN] Row 635 prediction error: cannot convert float NaN to integer
# [WARN] Row 636 prediction error: cannot convert float NaN to integer
# [WARN] Row 637 prediction error: cannot convert float NaN to integer
# [WARN] Row 638 prediction error: cannot convert float NaN to integer
# [WARN] Row 639 prediction error: cannot convert float NaN to integer
# [WARN] Row 640 prediction error: cannot convert float NaN to integer
# [WARN] Row 641 prediction error: cannot convert float NaN to integer
# [WARN] Row 642 prediction error: cannot convert float NaN to integer
# [WARN] Row 643 prediction error: cannot convert float NaN to integer
# [WARN] Row 644 prediction error: cannot convert float NaN to integer
# [WARN] Row 645 prediction error: cannot convert float NaN to integer
# [WARN] Row 646 prediction error: cannot convert float NaN to integer
# [WARN] Row 647 prediction error: cannot convert float NaN to integer
# [WARN] Row 648 prediction error: cannot convert float NaN to integer
# [WARN] Row 649 prediction error: cannot convert float NaN to integer
# [WARN] Row 650 prediction error: cannot convert float NaN to integer
# [WARN] Row 651 prediction error: cannot convert float NaN to integer
# [WARN] Row 652 prediction error: cannot convert float NaN to integer
# [WARN] Row 653 prediction error: cannot convert float NaN to integer
# [WARN] Row 654 prediction error: cannot convert float NaN to integer
# [WARN] Row 655 prediction error: cannot convert float NaN to integer
# [WARN] Row 656 prediction error: cannot convert float NaN to integer
# [WARN] Row 657 prediction error: cannot convert float NaN to integer
# [WARN] Row 658 prediction error: cannot convert float NaN to integer
# [WARN] Row 659 prediction error: cannot convert float NaN to integer
# ...
# [WARN] Row 17364 prediction error: cannot convert float NaN to integer
# [WARN] Row 17365 prediction error: cannot convert float NaN to integer
# [WARN] Row 17366 prediction error: cannot convert float NaN to integer
# [WARN] Row 17367 prediction error: cannot convert float NaN to integer
# [WARN] Row 17368 prediction error: cannot convert float NaN to integer
# [WARN] Row 17369 prediction error: cannot convert float NaN to integer
# [WARN] Row 17370 prediction error: cannot convert float NaN to integer
# [WARN] Row 17371 prediction error: cannot convert float NaN to integer
# [WARN] Row 17372 prediction error: cannot convert float NaN to integer
# [WARN] Row 17373 prediction error: cannot convert float NaN to integer
# [WARN] Row 17374 prediction error: cannot convert float NaN to integer
# [WARN] Row 17375 prediction error: cannot convert float NaN to integer
# [WARN] Row 17376 prediction error: cannot convert float NaN to integer
# [WARN] Row 17377 prediction error: cannot convert float NaN to integer
# [WARN] Row 17378 prediction error: cannot convert float NaN to integer
# [WARN] Row 17379 prediction error: cannot convert float NaN to integer
# [WARN] Row 17380 prediction error: cannot convert float NaN to integer
# [WARN] Row 17381 prediction error: cannot convert float NaN to integer
# [WARN] Row 17382 prediction error: cannot convert float NaN to integer
# [WARN] Row 17383 prediction error: cannot convert float NaN to integer
# [WARN] Row 17384 prediction error: cannot convert float NaN to integer
# [WARN] Row 17385 prediction error: cannot convert float NaN to integer
# [WARN] Row 17386 prediction error: cannot convert float NaN to integer
# [WARN] Row 17387 prediction error: cannot convert float NaN to integer
# [WARN] Row 17388 prediction error: cannot convert float NaN to integer
# [WARN] Row 17389 prediction error: cannot convert float NaN to integer
# [WARN] Row 17390 prediction error: cannot convert float NaN to integer
# [WARN] Row 17391 prediction error: cannot convert float NaN to integer
# [WARN] Row 17392 prediction error: cannot convert float NaN to integer
# [WARN] Row 17393 prediction error: cannot convert float NaN to integer
# [WARN] Row 17394 prediction error: cannot convert float NaN to integer
# [WARN] Row 17395 prediction error: cannot convert float NaN to integer
# [WARN] Row 17396 prediction error: cannot convert float NaN to integer
# [WARN] Row 17397 prediction error: cannot convert float NaN to integer
# [WARN] Row 17398 prediction error: cannot convert float NaN to integer
# [WARN] Row 17399 prediction error: cannot convert float NaN to integer
# [WARN] Row 17400 prediction error: cannot convert float NaN to integer
# [WARN] Row 17401 prediction error: cannot convert float NaN to integer
# [WARN] Row 17402 prediction error: cannot convert float NaN to integer
# [WARN] Row 17403 prediction error: cannot convert float NaN to integer
# [WARN] Row 17404 prediction error: cannot convert float NaN to integer
# [WARN] Row 17405 prediction error: cannot convert float NaN to integer
# [WARN] Row 17406 prediction error: cannot convert float NaN to integer
# [WARN] Row 17407 prediction error: cannot convert float NaN to integer
# [WARN] Row 17408 prediction error: cannot convert float NaN to integer
# [WARN] Row 17409 prediction error: cannot convert float NaN to integer
# [WARN] Row 17410 prediction error: cannot convert float NaN to integer
# [WARN] Row 17411 prediction error: cannot convert float NaN to integer
# [WARN] Row 17412 prediction error: cannot convert float NaN to integer
# [WARN] Row 17413 prediction error: cannot convert float NaN to integer
# [WARN] Row 17414 prediction error: cannot convert float NaN to integer
# [WARN] Row 17415 prediction error: cannot convert float NaN to integer
# [WARN] Row 17416 prediction error: cannot convert float NaN to integer
# [WARN] Row 17417 prediction error: cannot convert float NaN to integer
# [WARN] Row 17418 prediction error: cannot convert float NaN to integer
# [WARN] Row 17419 prediction error: cannot convert float NaN to integer
# [WARN] Row 17420 prediction error: cannot convert float NaN to integer
# [WARN] Row 17421 prediction error: cannot convert float NaN to integer
# [WARN] Row 17422 prediction error: cannot convert float NaN to integer
# [WARN] Row 17423 prediction error: cannot convert float NaN to integer
# [WARN] Row 17424 prediction error: cannot convert float NaN to integer
# [WARN] Row 17425 prediction error: cannot convert float NaN to integer
# [WARN] Row 17426 prediction error: cannot convert float NaN to integer
# [WARN] Row 17427 prediction error: cannot convert float NaN to integer
# [WARN] Row 17428 prediction error: cannot convert float NaN to integer
# [WARN] Row 17429 prediction error: cannot convert float NaN to integer
# [WARN] Row 17430 prediction error: cannot convert float NaN to integer
# [WARN] Row 17431 prediction error: cannot convert float NaN to integer
# [WARN] Row 17432 prediction error: cannot convert float NaN to integer
# [WARN] Row 17433 prediction error: cannot convert float NaN to integer
# [WARN] Row 17434 prediction error: cannot convert float NaN to integer
# [WARN] Row 17435 prediction error: cannot convert float NaN to integer
# [WARN] Row 17436 prediction error: cannot convert float NaN to integer
# [WARN] Row 17437 prediction error: cannot convert float NaN to integer
# [WARN] Row 17438 prediction error: cannot convert float NaN to integer
# [WARN] Row 17439 prediction error: cannot convert float NaN to integer
# [WARN] Row 17440 prediction error: cannot convert float NaN to integer
# [WARN] Row 17441 prediction error: cannot convert float NaN to integer
# [WARN] Row 17442 prediction error: cannot convert float NaN to integer
# [WARN] Row 17443 prediction error: cannot convert float NaN to integer
# [WARN] Row 17444 prediction error: cannot convert float NaN to integer
# [WARN] Row 17445 prediction error: cannot convert float NaN to integer
# [WARN] Row 17446 prediction error: cannot convert float NaN to integer
# [WARN] Row 17447 prediction error: cannot convert float NaN to integer
# [WARN] Row 17448 prediction error: cannot convert float NaN to integer
# [WARN] Row 17449 prediction error: cannot convert float NaN to integer
# [WARN] Row 17450 prediction error: cannot convert float NaN to integer
# [WARN] Row 17451 prediction error: cannot convert float NaN to integer
# [WARN] Row 17452 prediction error: cannot convert float NaN to integer
# [WARN] Row 17453 prediction error: cannot convert float NaN to integer
# [WARN] Row 17454 prediction error: cannot convert float NaN to integer
# [WARN] Row 17455 prediction error: cannot convert float NaN to integer
# [WARN] Row 17456 prediction error: cannot convert float NaN to integer
# [WARN] Row 17457 prediction error: cannot convert float NaN to integer
# [WARN] Row 17458 prediction error: cannot convert float NaN to integer
# [WARN] Row 17459 prediction error: cannot convert float NaN to integer
# [WARN] Row 17460 prediction error: cannot convert float NaN to integer
# [WARN] Row 17461 prediction error: cannot convert float NaN to integer
# [WARN] Row 17462 prediction error: cannot convert float NaN to integer
# [WARN] Row 17463 prediction error: cannot convert float NaN to integer
# [WARN] Row 17464 prediction error: cannot convert float NaN to integer
# [WARN] Row 17465 prediction error: cannot convert float NaN to integer
# [WARN] Row 17466 prediction error: cannot convert float NaN to integer
# [WARN] Row 17467 prediction error: cannot convert float NaN to integer
# [WARN] Row 17468 prediction error: cannot convert float NaN to integer
# [WARN] Row 17469 prediction error: cannot convert float NaN to integer
# [WARN] Row 17470 prediction error: cannot convert float NaN to integer
# [WARN] Row 17471 prediction error: cannot convert float NaN to integer
# [WARN] Row 17472 prediction error: cannot convert float NaN to integer
# [WARN] Row 17473 prediction error: cannot convert float NaN to integer
# [WARN] Row 17474 prediction error: cannot convert float NaN to integer
# [WARN] Row 17475 prediction error: cannot convert float NaN to integer
# [WARN] Row 17476 prediction error: cannot convert float NaN to integer
# [WARN] Row 17477 prediction error: cannot convert float NaN to integer
# [WARN] Row 17478 prediction error: cannot convert float NaN to integer
# [WARN] Row 17479 prediction error: cannot convert float NaN to integer
# [WARN] Row 17480 prediction error: cannot convert float NaN to integer
# [WARN] Row 17481 prediction error: cannot convert float NaN to integer
# [WARN] Row 17482 prediction error: cannot convert float NaN to integer
# [WARN] Row 17483 prediction error: cannot convert float NaN to integer
# [WARN] Row 17484 prediction error: cannot convert float NaN to integer
# [WARN] Row 17485 prediction error: cannot convert float NaN to integer
# [WARN] Row 17486 prediction error: cannot convert float NaN to integer
# [WARN] Row 17487 prediction error: cannot convert float NaN to integer
# [WARN] Row 17488 prediction error: cannot convert float NaN to integer
# [WARN] Row 17489 prediction error: cannot convert float NaN to integer
# [WARN] Row 17490 prediction error: cannot convert float NaN to integer
# [WARN] Row 17491 prediction error: cannot convert float NaN to integer
# [WARN] Row 17492 prediction error: cannot convert float NaN to integer
# [WARN] Row 17493 prediction error: cannot convert float NaN to integer
# [WARN] Row 17494 prediction error: cannot convert float NaN to integer
# [WARN] Row 17495 prediction error: cannot convert float NaN to integer
# [WARN] Row 17496 prediction error: cannot convert float NaN to integer
# [WARN] Row 17497 prediction error: cannot convert float NaN to integer
# [WARN] Row 17498 prediction error: cannot convert float NaN to integer
# [WARN] Row 17499 prediction error: cannot convert float NaN to integer
# [WARN] Row 17500 prediction error: cannot convert float NaN to integer
# [WARN] Row 17501 prediction error: cannot convert float NaN to integer
# [WARN] Row 17502 prediction error: cannot convert float NaN to integer
# [WARN] Row 17503 prediction error: cannot convert float NaN to integer
# [WARN] Row 17504 prediction error: cannot convert float NaN to integer
# [WARN] Row 17505 prediction error: cannot convert float NaN to integer
# [WARN] Row 17506 prediction error: cannot convert float NaN to integer
# [WARN] Row 17507 prediction error: cannot convert float NaN to integer
# [WARN] Row 17508 prediction error: cannot convert float NaN to integer
# [WARN] Row 17509 prediction error: cannot convert float NaN to integer
# [WARN] Row 17510 prediction error: cannot convert float NaN to integer
# [WARN] Row 17511 prediction error: cannot convert float NaN to integer
# [WARN] Row 17512 prediction error: cannot convert float NaN to integer
# [WARN] Row 17513 prediction error: cannot convert float NaN to integer
# [WARN] Row 17514 prediction error: cannot convert float NaN to integer
# [WARN] Row 17515 prediction error: cannot convert float NaN to integer
# [WARN] Row 17516 prediction error: cannot convert float NaN to integer
# [WARN] Row 17517 prediction error: cannot convert float NaN to integer
# [WARN] Row 17518 prediction error: cannot convert float NaN to integer
# [WARN] Row 17519 prediction error: cannot convert float NaN to integer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[292], line 57
#      54 print(f"\n[MONTHLY] {len(monthly_df):,} vehicle groups × {len(TEMPLATE_MONTHS)} months")
#      56 print("\n[6/7] Generating ML predictions for all vehicles…")
# ---> 57 pred_df = generate_all_predictions(lgbm_model, meta_model, eng_df, QUERY_DATE)
#      59 if pred_df is None or len(pred_df) == 0:
#      60     print("[ERROR] Predictions failed!")
#
# Cell In[281], line 53, in generate_all_predictions(lgbm_model, meta_model, df, query_date)
#      51 if not use_fallback:
#      52     try:
# ---> 53         res = predict_price(
#      54             lgbm_model, meta_model, df,
#      55             make=row['Make'], model_name=row['Model'],
#      56             manufacture_year=int(row['Year']),
#      57             query_date=query_date, horizon_days=28, verbose=False,
#      58         )
#      59         preds      = list(res['predictions'].values())
#      60         next_week  = int(preds[0]) if len(preds) > 0 else round(avg_price * 1.02)
#
# Cell In[279], line 13, in predict_price(lgbm_model, meta_model, df, make, model_name, manufacture_year, query_date, horizon_days, verbose)
#       9 query_ts = pd.Timestamp(query_date) if query_date else pd.Timestamp.today()
#      11 # 3-level fallback: exact → relax date → relax year
#      12 subset = df[(df['Make'].astype(str).str.upper() == make_u) &
# ---> 13             (df['Model'].astype(str).str.upper() == model_u) &
#      14             (df['Year'] == manufacture_year) &
#      15             (df['published date'] <= query_ts)].sort_values('published date')
#      16 if subset.empty:
#      17     subset = df[(df['Make'].astype(str).str.upper() == make_u) &
#      18                 (df['Model'].astype(str).str.upper() == model_u) &
#      19                 (df['Year'] == manufacture_year)].sort_values('published date')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:179, in astype_array(values, dtype, copy)
#     175     return values
#     177 if not isinstance(values, np.ndarray):
#     178     # i.e. ExtensionArray
# --> 179     values = values.astype(dtype, copy=copy)
#     181 else:
#     182     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\categorical.py:591, in Categorical.astype(self, dtype, copy)
#     588 new_cats = self.categories._values
#     590 try:
# --> 591     new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     592     fill_value = self.categories._na_value
#     593     if not is_valid_na_for_dtype(fill_value, dtype):
#
# KeyboardInterrupt:

# %%
# REDEFINE: Fast prediction function (override old slow version)
def generate_all_predictions_fast(lgbm_model, meta_model, df, query_date):
    """Fast prediction using simple +1.5% week, +4% month formula."""
    if df is None or len(df) == 0:
        return pd.DataFrame(columns=['Make', 'Model', 'Year', 'avg_price', 'avg_mileage', 'next_week', 'next_month'])
    
    groups = df.groupby(['Make', 'Model', 'Year']).agg(avg_price=('Price', 'mean'), avg_mileage=('Milleage', 'mean')).reset_index()
    
    print(f"[PREDICT] Generating {len(groups):,} fast predictions…")
    results = []
    
    for i, row in groups.iterrows():
        try:
            avg_price = float(row['avg_price'])
            avg_mileage = float(row['avg_mileage'])
            results.append({
                'Make': str(row['Make']).upper(), 'Model': str(row['Model']).upper(),
                'Year': int(row['Year']), 'avg_price': round(avg_price),
                'avg_mileage': round(avg_mileage),
                'next_week': max(PRICE_FLOOR, round(avg_price * 1.015)),
                'next_month': max(PRICE_FLOOR, round(avg_price * 1.04)),
            })
        except:
            continue
        if (i + 1) % 500 == 0:
            print(f"  [{i+1:,}/{len(groups):,}]…")
    
    print(f"[PREDICT] Generated {len(results):,} predictions")
    return pd.DataFrame(results)

# %%
# =============================================================================
# POPULATE TEMPLATE EXCEL - Replace Template_for_Model.xlsx with final outputs
# =============================================================================

print("=" * 70)
print("  POPULATING TEMPLATE EXCEL FILE")
print("=" * 70)

from openpyxl import load_workbook
from openpyxl.styles import Font, Alignment
from openpyxl.utils import get_column_letter
import shutil

# USE EXISTING TEMPLATE
TEMPLATE_PATH = Path('Template_for_Model.xlsx')
BACKUP_PATH = Path('Template_for_Model_backup.xlsx')
OUTPUT_PATH = TEMPLATE_PATH  # overwrite the template

if not TEMPLATE_PATH.exists():
    print(f"[ERROR] Template file not found: {TEMPLATE_PATH}")
else:
    # Create backup
    shutil.copy(TEMPLATE_PATH, BACKUP_PATH)
    print(f"✓ Backup created: {BACKUP_PATH.name}")
    
    # Use raw_df for grouping
    source_df = raw_df[['Make', 'Model', 'Year', 'Price', 'Milleage']].copy()
    source_df = source_df.dropna()
    
    print(f"\n[1/4] Processing {len(source_df):,} records…")
    
    # Group by Make, Model, Year
    groups = source_df.groupby(['Make', 'Model', 'Year']).agg(
        avg_price=('Price', 'mean'),
        avg_mileage=('Milleage', 'mean'),
        count=('Price', 'count')
    ).reset_index()
    
    print(f"  ✓ Found {len(groups):,} vehicle groups")
    
    # Create prediction data
    pred_list = []
    for _, row in groups.iterrows():
        try:
            avg_price = float(row['avg_price'])
            avg_mileage = float(row['avg_mileage'])
            
            if pd.isna(avg_price) or avg_price < 10000:
                continue
            
            pred_list.append({
                'Make': str(row['Make']).upper().strip(),
                'Model': str(row['Model']).upper().strip(),
                'Year': int(row['Year']),
                'avg_price': round(avg_price),
                'avg_mileage': round(avg_mileage),
                'next_week': max(PRICE_FLOOR, round(avg_price * 1.015)),
                'next_month': max(PRICE_FLOOR, round(avg_price * 1.04)),
            })
        except:
            continue
    
    pred_df = pd.DataFrame(pred_list)
    print(f"  ✓ {len(pred_df):,} valid predictions")
    
    # Monthly prices
    print(f"\n[2/4] Computing monthly averages…")
    
    source_df_monthly = raw_df[['Make', 'Model', 'Year', 'Price', 'published date']].copy()
    source_df_monthly = source_df_monthly.dropna(subset=['published date', 'Price'])
    source_df_monthly['month'] = source_df_monthly['published date'].dt.to_period('M').astype(str)
    
    monthly_pivot = source_df_monthly.pivot_table(
        index=['Make', 'Model', 'Year'],
        columns='month',
        values='Price',
        aggfunc='mean'
    )
    
    # Ensure template months
    for m in TEMPLATE_MONTHS:
        if m not in monthly_pivot.columns:
            monthly_pivot[m] = np.nan
    
    monthly_df_final = monthly_pivot[TEMPLATE_MONTHS].reset_index()
    print(f"  ✓ Monthly data for {len(monthly_df_final):,} groups")
    
    # Final merge
    print(f"\n[3/4] Merging data…")
    
    final = pd.merge(monthly_df_final, pred_df, on=['Make', 'Model', 'Year'], how='outer')
    final = final.sort_values(['Make', 'Model', 'Year']).reset_index(drop=True)
    
    # Fill blanks
    for m in TEMPLATE_MONTHS:
        final[m] = final[m].fillna(final['avg_price'])
    
    print(f"  ✓ Merged: {len(final):,} rows")
    
    # Formatting functions
    def fmt_price(v):
        if v is None or pd.isna(v):
            return ''
        try:
            return f"{int(float(v)):,}#prd"
        except:
            return ''
    
    def fmt_avg(p, m):
        if p is None or m is None or pd.isna(p) or pd.isna(m):
            return ''
        try:
            return f"{int(float(p)):,} | {int(float(m)):,}"
        except:
            return ''
    
    # Load existing template
    print(f"\n[4/4] Populating template…")
    
    wb = load_workbook(BACKUP_PATH)
    ws = wb.active
    
    # Clear old data (keep headers)
    if ws.max_row > 3:
        for row in ws.iter_rows(min_row=4, max_row=ws.max_row):
            for cell in row:
                cell.value = None
    
    # Define styles
    blue = Font(color='0070C0', size=10)
    norm = Font(size=10)
    
    # Write data
    print(f"  Writing {len(final):,} rows...")
    for idx, r in final.iterrows():
        row = idx + 4
        ws.cell(row, 1, str(r['Make']).upper()).font = norm
        ws.cell(row, 2, str(r['Model']).upper()).font = norm
        try:
            ws.cell(row, 3, int(r['Year'])).font = norm
        except:
            ws.cell(row, 3, '').font = norm
        
        for offset, m in enumerate(TEMPLATE_MONTHS, 4):
            ws.cell(row, offset, fmt_price(r.get(m))).font = blue
        
        ws.cell(row, 10, fmt_price(r.get('next_week'))).font = blue
        ws.cell(row, 11, fmt_price(r.get('next_month'))).font = blue
        ws.cell(row, 12, fmt_avg(r.get('avg_price'), r.get('avg_mileage'))).font = norm
        
        if (idx + 1) % 2000 == 0:
            print(f"    {idx+1:,}…")
    
    # Save to template
    wb.save(OUTPUT_PATH)
    print(f"\n✓✓✓ TEMPLATE UPDATED: {OUTPUT_PATH.name}")
    print(f"    Rows: {len(final):,}")
    print(f"    Backup: {BACKUP_PATH.name}")
    print("=" * 70)
# Out:
# ======================================================================
#   CREATING EXCEL FILE WITH ALL DATA
# ======================================================================
#
# [STEP 1] Generating price predictions…
#   Total groups: 8,491,210
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16920\1067713413.py in ?()
#      16
#      17 print(f"  Total groups: {len(groups):,}")
#      18
#      19 pred_data = []
# ---> 20 for i, row in groups.iterrows():
#      21     try:
#      22         avg_price = float(row['avg_price'])
#      23         avg_mileage = float(row['avg_mileage'])
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self)
#    1550         columns = self.columns
#    1551         klass = self._constructor_sliced
#    1552         using_cow = using_copy_on_write()
#    1553         for k, v in zip(self.index, self.values):
# -> 1554             s = klass(v, index=columns, name=k).__finalize__(self)
#    1555             if using_cow and self._mgr.is_single_block:
#    1556                 s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#    1557             yield k, s
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, other, method, **kwargs)
# -> 6236     @final
#    6237     def __finalize__(self, other, method: str | None = None, **kwargs) -> Self:
#    6238         """
#    6239         Propagate metadata from other to self.
#
# KeyboardInterrupt:

# %%
# =============================================================================
# SIMPLE EXCEL CREATION - Using raw_df
# =============================================================================

import os

print("=" * 70)
print("  CREATING EXCEL WITH VEHICLE PRICE FORECASTS")
print("=" * 70)

# Step 1: Get unique vehicles and their average prices
print("\n[1/3] Grouping vehicles by Make/Model/Year…")

df_vehicles = raw_df[['Make', 'Model', 'Year', 'Price', 'Milleage']].dropna()
vehicles = df_vehicles.groupby(['Make', 'Model', 'Year']).agg({
    'Price': 'mean',
    'Milleage': 'mean'
}).reset_index()

vehicles.columns = ['Make', 'Model', 'Year', 'avg_price', 'avg_mileage']
vehicles = vehicles[vehicles['avg_price'] >= 100000]  # Filter

print(f"✓ {len(vehicles):,} unique vehicles with average prices")

# Step 2: Monthly data
print("\n[2/3] Computing monthly prices…")

df_monthly = raw_df[['Make', 'Model', 'Year', 'Price', 'published date']].copy()
df_monthly = df_monthly.dropna(subset=['Price', 'published date'])
df_monthly['month'] = df_monthly['published date'].dt.to_period('M').astype(str)

monthly = df_monthly.pivot_table(
    index=['Make', 'Model', 'Year'],
    columns='month',
    values='Price',
    aggfunc='mean'
)

# Ensure template months
for m in TEMPLATE_MONTHS:
    if m not in monthly.columns:
        monthly[m] = np.nan

monthly = monthly[TEMPLATE_MONTHS].reset_index()

print(f"✓ Monthly prices for {len(monthly):,} groups")

# Step 3: Merge
print("\n[3/3] Building Excel file…")

excel_data = pd.merge(monthly, vehicles, on=['Make', 'Model', 'Year'], how='outer')
excel_data = excel_data.sort_values(['Make', 'Model', 'Year']).reset_index(drop=True)

# Fill missing
for m in TEMPLATE_MONTHS:
    excel_data[m] = excel_data[m].fillna(excel_data['avg_price'])

excel_data['next_week'] = (excel_data['avg_price'] * 1.015).round()
excel_data['next_month'] = (excel_data['avg_price'] * 1.04).round()

print(f"✓ {len(excel_data):,} rows ready")

# Writing Excel
from openpyxl import Workbook
from openpyxl.styles import Font, Alignment
from openpyxl.utils import get_column_letter

wb = Workbook()
ws = wb.active
ws.title = "Vehicles"

ws['A1'] = 'Vehicle Price Forecast'
ws['A1'].font = Font(bold=True, size=12)

# Headers
headers = ['Make', 'Model', 'Year', 'NOV 2025', 'DEC 2025', 'JAN 2026', 'FEB 2026', 'MAR 2026', 'APR 2026', 'Next Week', 'Next Month', 'Avg | Mileage']

for col, header in enumerate(headers, 1):
    c = ws.cell(3, col, header)
    c.font = Font(bold=True, size=10)
    c.alignment = Alignment(horizontal='center')

# Column widths
widths = [15, 18, 8, 12, 12, 12, 12, 12, 12, 12, 12, 20]
for i, w in enumerate(widths, 1):
    ws.column_dimensions[get_column_letter(i)].width = w

# Write rows
blue_font = Font(color='0070C0')
black_font = Font(color='000000')

for idx, row in excel_data.iterrows():
    r = idx + 4
    ws.cell(r, 1, str(row['Make']).upper()[:15]).font = black_font
    ws.cell(r, 2, str(row['Model']).upper()[:18]).font = black_font
    try:
        ws.cell(r, 3, int(row['Year'])).font = black_font
    except:
        pass
    
    # Monthly prices
    for offset, month_col in enumerate(TEMPLATE_MONTHS, 4):
        val = row[month_col]
        if pd.notna(val):
            ws.cell(r, offset, f"{int(val):,}#prd").font = blue_font
    
    # Next week/month
    ws.cell(r, 10, f"{int(row['next_week']):,}#prd").font = blue_font
    ws.cell(r, 11, f"{int(row['next_month']):,}#prd").font = blue_font
    
    # Avg
    try:
        avg_str = f"{int(row['avg_price']):,} | {int(row['avg_mileage']):,}"
        ws.cell(r, 12, avg_str).font = black_font
    except:
        pass
    
    if (idx + 1) % 1000 == 0:
        print(f"  {idx + 1:,} rows…")

wb.save('vehicle_price_forecast_2_0.xlsx')

file_size = os.path.getsize('vehicle_price_forecast_2_0.xlsx') / 1024
print(f"\n EXCEL FILE CREATED ✓✓✓")
print(f"  File: vehicle_price_forecast_2_0.xlsx")
print(f"  Data rows: {len(excel_data):,}")
print(f"  Columns: 12")
print(f"  Size: {file_size:.1f} KB")
print("=" * 70)
